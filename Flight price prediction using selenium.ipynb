# %%
import selenium
from selenium import webdriver

# %%
driver=webdriver.Chrome(r'/Users/NomaanSayed/Desktop/Webdriver/chromedriver' )

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=GOI&destinationCountry=IN&flexi=0&flight_depart_date=16%2F05%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=1382402317979&viewName=normal'
driver.get(url)

# %%
Airlane_name=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
Airlane_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d76a9db2-d970-49fa-9a4a-8b205b70f9fa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="848525ed-e9ea-4d9f-8f87-e531e9951f0b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="53b7f431-320b-49a9-9397-1659ff99e29a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ce12ad91-cc46-4176-884d-15d38fb8e147")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d50c9f4e-1623-41d4-8871-b383db1838a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="15746e9c-d41b-4f1d-9ec8-85225ebe0943")>,
# ...

# %%
Airline=[]
for i in Airlane_name:
    Airline.append(i.text)
Airline
# Out:
# ['Go First',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
# ...

# %%
arr_flight=driver.find_elements_by_xpath("//div [@class='fs-15 bold time']")
arr_flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="6d064ff2-4509-4253-99d5-23fd768f3d1a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="2db18365-91b7-4cd4-b785-7946ade1a4c3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="5c381e54-b2b8-4b30-b2f5-da1b70334c32")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="2e688da8-b8a2-46b2-844e-07cfc1ed8494")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="caeede88-e7d4-452e-976c-09a0093ac7ac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9ad0c49a-9fed-48e5-a5fc-22ba2adb44de")>,
# ...

# %%
Arrival=[]
for i in arr_flight:
    Arrival.append(i.text)
Arrival
# Out:
# ['13:50',
#  '19:05',
#  '22:55',
#  '07:20',
#  '12:10',
#  '23:00',
#  '10:10',
#  '20:40',
#  '21:15',
#  '08:05',
#  '08:00',
#  '10:00',
#  '19:00',
#  '18:00',
#  '15:25',
#  '07:05',
#  '23:55',
#  '06:00',
#  '19:30',
#  '07:20',
#  '20:30',
#  '10:15',
#  '10:30',
#  '11:10',
#  '17:45',
#  '17:45',
#  '17:45',
#  '11:10',
#  '11:10',
#  '02:40',
#  '05:00',
#  '06:05',
#  '09:20',
#  '13:45',
#  '17:15',
#  '18:30',
#  '19:30',
#  '07:00',
#  '07:45',
#  '08:30',
#  '09:55',
#  '15:50',
#  '20:30',
#  '22:20',
#  '11:35',
#  '21:15',
#  '19:25',
#  '21:15',
#  '19:25',
#  '21:15',
#  '19:25',
#  '05:20',
#  '09:00',
#  '05:20',
#  '09:00',
#  '05:20',
#  '09:00',
#  '14:20',
#  '17:50',
#  '19:25',
#  '19:25',
#  '05:45',
#  '19:25',
#  '19:00',
#  '19:00',
#  '05:35',
#  '17:10',
#  '09:30',
#  '16:50',
#  '18:55',
#  '16:50',
#  '00:30',
#  '00:30',
#  '20:55',
#  '20:55',
#  '09:30',
#  '06:10',
#  '06:10',
#  '09:30',
#  '06:10',
#  '16:45',
#  '19:20',
#  '13:30',
# ...

# %%
dp_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
dp_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="60614cad-30a4-4cea-872d-e7d956fd3f41")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d6bca1a2-02e1-4b79-abf4-feb9b5bf34b3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="04e61629-3688-42ef-8e36-77f374519915")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ce5023a4-1040-468a-86b3-1e413c60adb6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c877ad5c-fd47-4aa4-b587-1cc26c9f7862")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="39befa3e-5387-4c89-9ad5-2a6f8603aab6")>,
# ...

# %%
Departure=[]
for i in dp_time:
    Departure.append(i.text.replace("\n"," "))
Departure
# Out:
# ['15:55',
#  '21:10',
#  '01:00 + 1 day',
#  '09:30',
#  '14:20',
#  '01:10 + 1 day',
#  '12:25',
#  '22:55',
#  '23:30',
#  '10:15',
#  '10:15',
#  '12:15',
#  '21:15',
#  '20:30',
#  '19:10',
#  '11:10',
#  '01:55 + 1 day',
#  '08:05',
#  '21:30',
#  '09:35',
#  '22:35',
#  '12:30',
#  '15:55',
#  '18:00',
#  '21:00 + 1 day',
#  '23:55',
#  '20:25 + 1 day',
#  '21:35',
#  '08:30 + 1 day',
#  '04:50',
#  '07:10',
#  '08:15',
#  '11:30',
#  '15:55',
#  '19:25',
#  '20:40',
#  '21:40',
#  '09:15',
#  '10:00',
#  '10:45',
#  '12:10',
#  '18:05',
#  '22:45',
#  '00:35 + 1 day',
#  '13:55',
#  '08:55 + 1 day',
#  '08:55 + 1 day',
#  '12:20 + 1 day',
#  '12:20 + 1 day',
#  '18:30 + 1 day',
#  '18:30 + 1 day',
#  '13:00',
#  '19:50',
#  '19:50',
#  '08:55 + 1 day',
#  '08:55 + 1 day',
#  '13:00 + 1 day',
#  '16:30 + 1 day',
#  '01:00 + 1 day',
#  '23:25',
#  '09:25 + 1 day',
#  '23:25',
#  '15:55 + 1 day',
#  '03:40 + 1 day',
#  '11:15 + 1 day',
#  '03:40 + 1 day',
#  '22:40',
#  '16:15',
# ...

# %%
ar_price=driver.find_elements_by_xpath("//div [@class='i-b tipsy fare-summary-tooltip fs-18']")
ar_price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="eae6ec20-2aa2-4d21-b7fe-e896a5bd18c3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="daffa6fb-57fb-4c32-8685-04204e70b884")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="82dde87a-9405-4c2e-810e-d81157965c82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ae5e857a-c91b-429b-be76-f3740c368940")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="a07ef0b8-d60b-4b85-b135-46d40ce02c00")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="292fa04b-6748-460b-a998-3072389e437f")>,
# ...

# %%
Price=[]
for i in ar_price:
    Price.append(i.text)
Price
# Out:
# ['2,339',
#  '2,339',
#  '2,339',
#  '2,339',
#  '2,339',
#  '2,339',
#  '2,339',
#  '2,339',
#  '2,339',
#  '2,463',
#  '2,464',
#  '2,464',
#  '2,464',
#  '2,464',
#  '2,464',
#  '2,464',
#  '2,748',
#  '2,748',
#  '2,930',
#  '2,930',
#  '3,244',
#  '3,244',
#  '3,477',
#  '3,542',
#  '3,654',
#  '3,665',
#  '3,665',
#  '3,762',
#  '3,762',
#  '3,789',
#  '3,789',
#  '3,789',
#  '3,789',
#  '3,789',
#  '3,789',
#  '3,789',
#  '3,789',
#  '3,789',
#  '3,789',
#  '3,789',
#  '3,789',
#  '3,789',
#  '3,789',
#  '3,789',
#  '3,789',
#  '3,819',
#  '3,819',
#  '3,819',
#  '3,819',
#  '3,819',
#  '3,819',
#  '3,843',
#  '3,843',
#  '3,843',
#  '3,843',
#  '3,843',
#  '3,843',
#  '4,095',
#  '4,118',
#  '4,149',
#  '4,149',
#  '4,149',
#  '4,149',
#  '4,221',
#  '4,221',
#  '4,221',
#  '4,456',
#  '4,768',
#  '4,822',
#  '4,822',
#  '4,822',
#  '4,822',
#  '4,822',
#  '4,822',
#  '4,822',
#  '4,912',
#  '4,912',
#  '4,912',
#  '4,912',
#  '4,912',
#  '4,912',
#  '4,917',
#  '4,917',
# ...

# %%
ar_dr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
ar_dr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="7914b337-091a-4571-8bc0-320e7a422cf6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="31b953d9-a21e-4f5b-96e8-4796e97982ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="6dde2f4e-cf77-4cae-8ac6-c6b965acc6dd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="e2168a8c-08e9-4a9c-9adb-7e8c492f9d12")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c829c166-09a8-40dc-8ca9-538148f261c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="66113874-a64c-4eac-89f7-11ac1ca7e893")>,
# ...

# %%
Duration=[]
for i in ar_dr:
    Duration.append(i.text)
Duration
# Out:
# ['2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 30m',
#  '3h 45m',
#  '4h 05m',
#  '2h 00m',
#  '2h 05m',
#  '2h 00m',
#  '2h 15m',
#  '2h 05m',
#  '2h 15m',
#  '5h 25m',
#  '6h 50m',
#  '27h 15m',
#  '6h 10m',
#  '26h 40m',
#  '10h 25m',
#  '21h 20m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '11h 40m',
#  '13h 30m',
#  '15h 05m',
#  '16h 55m',
#  '21h 15m',
#  '23h 05m',
#  '7h 40m',
#  '10h 50m',
#  '14h 30m',
#  '23h 55m',
#  '27h 35m',
#  '28h 00m',
#  '26h 10m',
#  '7h 10m',
#  '4h 00m',
#  '14h 00m',
#  '17h 40m',
#  '20h 30m',
#  '8h 40m',
#  '16h 15m',
#  '22h 05m',
#  '5h 30m',
#  '6h 45m',
#  '4h 10m',
#  '4h 20m',
#  '6h 25m',
#  '7h 10m',
#  '8h 55m',
#  '8h 55m',
#  '10h 45m',
# ...

# %%
sr_name=driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
sr_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="cfb8df8e-c371-4233-a2bc-a77be824b58a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="393b995b-d3b4-485f-87c6-3533a83e20f3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="e4ffbecf-d113-4a3e-8fe5-55e4bd62107b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="da0a3f20-5afb-45ee-804c-f8687b0bcb34")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="2669fbec-af3b-4889-8143-3e3133a4bde2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="1edcca73-76ad-4f4f-9e5c-cff2aa6f5a09")>,
# ...

# %%
Source=[]
for i in sr_name:
    Source.append(i.text)
Source
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
Ds_name=driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]")
Ds_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="370059da-7955-46a2-994b-91fb9a22b6ad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="a03ae7b9-0f0d-46ae-800c-c1e041a2f39b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d3e0b732-0c98-4372-acf9-600ced15fb7d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="aac72733-77f2-4bb4-8482-097b61b4d7de")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9ba5acb6-788b-4bd9-9d17-8161345d2985")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b8f483a1-d8ee-4d92-8537-4840197c153b")>,
# ...

# %%
Destination=[]
for i in Ds_name:
    Destination.append(i.text)
Destination
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame({"Airline":Airline,"Arrival":Arrival,"Departure":Departure,"Duration":Duration,"Source":Source,"Destination":Destination,"Price":Price})
df
# Out:
#       Airline Arrival      Departure Duration  Source Destination  Price
# 0    Go First   13:50          15:55   2h 05m  Mumbai   New Delhi  2,339
# 1    Go First   19:05          21:10   2h 05m  Mumbai   New Delhi  2,339
# 2    Air Asia   22:55  01:00 + 1 day   2h 05m  Mumbai   New Delhi  2,339
# 3    Air Asia   07:20          09:30   2h 10m  Mumbai   New Delhi  2,339
# 4    Go First   12:10          14:20   2h 10m  Mumbai   New Delhi  2,339
# ..        ...     ...            ...      ...     ...         ...    ...
# 150  SpiceJet   16:05  11:20 + 1 day  19h 15m  Mumbai   New Delhi  8,102
# 151   Vistara   12:15          16:45   4h 30m  Mumbai   New Delhi  8,148
# 152  Go First   12:00          19:20   7h 20m  Mumbai   New Delhi  9,092
# 153  Go First   12:00          19:50   7h 50m  Mumbai   New Delhi  9,092
# 154  Go First   12:00          20:50   8h 50m  Mumbai   New Delhi  9,092
#
# [155 rows x 7 columns]

# %%
#bom to goa

# %%
ar1_dr=driver.find_elements_by_xpath("//span [@class='i-b text ellipsis']")
ar1_dr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="572026e4-8373-4ab3-b507-3820bad07243")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="477439b1-a166-4b9a-b041-bcacdc64cb95")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="fe82d968-5450-4b68-b415-e4b9343038ba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c6b526b2-2248-4325-ac7c-e65af7385a0d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="cadff7bc-a4c9-454d-86e5-fefe41a33fbc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="48d78e6c-ebcb-44ea-9e38-8d4871abf3eb")>,
# ...

# %%
Airline=[]
for i in ar1_dr:
    Airline.append(i.text)
Airline
# Out:
# ['Air India',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
# ...

# %%
ar2_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
ar2_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3212692f-0b51-4808-a292-351e2e485427")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c92cc8e9-da32-40c8-b0ce-7d752e1fb75e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b5a37f27-dec4-4f0c-8721-2861426d6117")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c9eeb981-69cd-4eea-a308-870787f20812")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="0a353215-6e08-4c2e-b1e0-beaab97269f5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="2d76300c-d7a9-4ff7-8c00-b2358b0c9ca3")>,
# ...

# %%
Arrival=[]
for i in ar2_time:
    Arrival.append(i.text)
Arrival
# Out:
# ['05:05',
#  '13:25',
#  '21:00',
#  '05:00',
#  '11:30',
#  '22:00',
#  '15:20',
#  '16:35',
#  '23:35',
#  '04:45',
#  '00:25',
#  '21:30',
#  '11:30',
#  '15:35',
#  '16:55',
#  '05:00',
#  '11:15',
#  '14:00',
#  '21:30',
#  '11:25',
#  '21:15',
#  '19:25',
#  '06:05',
#  '21:20',
#  '20:10',
#  '20:10',
#  '13:05',
#  '09:30',
#  '06:10',
#  '13:30',
#  '07:35',
#  '19:05',
#  '13:50',
#  '12:10',
#  '10:10',
#  '23:00',
#  '21:15',
#  '20:40',
#  '07:20',
#  '07:20',
#  '22:55',
#  '07:20',
#  '22:55',
#  '08:05',
#  '18:00',
#  '15:25',
#  '10:00',
#  '08:00',
#  '07:05',
#  '19:00',
#  '19:00',
#  '18:00',
#  '18:00',
#  '15:25',
#  '15:25',
#  '15:25',
#  '10:00',
#  '10:00',
#  '10:00',
#  '08:00',
#  '06:00',
#  '23:55',
#  '17:45',
#  '17:45',
#  '10:00',
#  '08:00',
#  '07:05',
#  '19:00',
#  '19:00',
#  '18:00',
#  '18:00',
#  '15:25',
#  '15:25',
#  '15:25',
#  '10:00',
#  '06:30',
#  '06:00',
#  '22:45',
#  '21:55',
#  '20:55',
#  '19:45',
#  '18:30',
#  '17:35',
# ...

# %%
dr2_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
dr2_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="6c9b1e74-5947-4975-9457-d7e140cdb712")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="22a294a6-421a-4cc6-930b-fce4c2e3168f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="1bfb7208-821e-4e17-8398-4f83c53570f3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="2b377b95-26c1-4d4b-bc3d-482f901939d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d330813b-402d-4587-9b9e-10e9dbe81fc7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3b4d4a89-9939-432d-bb25-7922f8b857ea")>,
# ...

# %%
Departure=[]
for i in dr2_time:
    Departure.append(i.text.replace("\n"," "))
Departure
# Out:
# ['06:25',
#  '14:45',
#  '22:35',
#  '06:15',
#  '12:45',
#  '23:20',
#  '16:45',
#  '18:00',
#  '00:35 + 1 day',
#  '05:55',
#  '01:45',
#  '22:55',
#  '13:00',
#  '17:05',
#  '18:15',
#  '06:25',
#  '12:40',
#  '15:25',
#  '22:55',
#  '12:45',
#  '17:00 + 1 day',
#  '17:00 + 1 day',
#  '16:55',
#  '07:00 + 1 day',
#  '07:00 + 1 day',
#  '07:00 + 1 day',
#  '22:00',
#  '20:30',
#  '20:30',
#  '20:00',
#  '20:00',
#  '20:30',
#  '23:05',
#  '23:05',
#  '23:05',
#  '13:20 + 1 day',
#  '13:20 + 1 day',
#  '13:20 + 1 day',
#  '14:55',
#  '15:25',
#  '07:50 + 1 day',
#  '22:35',
#  '14:55 + 1 day',
#  '23:05',
#  '00:35 + 1 day',
#  '00:35 + 1 day',
#  '00:35 + 1 day',
#  '00:35 + 1 day',
#  '00:35 + 1 day',
#  '17:00 + 1 day',
#  '17:00 + 1 day',
#  '17:00 + 1 day',
#  '17:00 + 1 day',
#  '17:00 + 1 day',
#  '17:00 + 1 day',
#  '17:00 + 1 day',
#  '17:00 + 1 day',
#  '17:00 + 1 day',
#  '17:00 + 1 day',
#  '17:00 + 1 day',
#  '13:20',
#  '13:20 + 1 day',
#  '00:35 + 2 days',
# ...

# %%
duration_flight=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
duration_flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ccf83ffa-8899-4c08-9111-4992756cf910")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="f247fb1d-6ef3-4f9b-b42e-3e9ee7156d3a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="cdeedf5a-e6cd-4ee3-b85b-b4139119db44")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="e1062f2c-7f26-4572-bf7b-caaf40de32b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="cd30af68-06fe-46c3-8580-59fdd3370cdd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="f177d1e0-e0c5-444e-96d5-6b028d4cd7c0")>,
# ...

# %%
Duration=[]
for i in duration_flight:
    Duration.append(i.text)
Duration
# Out:
# ['1h 20m',
#  '1h 20m',
#  '1h 35m',
#  '1h 15m',
#  '1h 15m',
#  '1h 20m',
#  '1h 25m',
#  '1h 25m',
#  '1h 00m',
#  '1h 10m',
#  '1h 20m',
#  '1h 25m',
#  '1h 30m',
#  '1h 30m',
#  '1h 20m',
#  '1h 25m',
#  '1h 25m',
#  '1h 25m',
#  '1h 25m',
#  '1h 20m',
#  '19h 45m',
#  '21h 35m',
#  '10h 50m',
#  '9h 40m',
#  '10h 50m',
#  '10h 50m',
#  '8h 55m',
#  '11h 00m',
#  '14h 20m',
#  '6h 30m',
#  '12h 25m',
#  '1h 25m',
#  '9h 15m',
#  '10h 55m',
#  '12h 55m',
#  '14h 20m',
#  '16h 05m',
#  '16h 40m',
#  '7h 35m',
#  '8h 05m',
#  '8h 55m',
#  '15h 15m',
#  '16h 00m',
#  '15h 00m',
#  '6h 35m',
#  '9h 10m',
#  '14h 35m',
#  '16h 35m',
#  '17h 30m',
#  '22h 00m',
#  '22h 00m',
#  '23h 00m',
#  '23h 00m',
#  '25h 35m',
#  '25h 35m',
#  '25h 35m',
#  '31h 00m',
#  '31h 00m',
#  '31h 00m',
#  '33h 00m',
#  '7h 20m',
#  '13h 25m',
#  '30h 50m',
#  '30h 50m',
#  '10h 30m',
#  '12h 30m',
#  '13h 25m',
#  '25h 30m',
#  '25h 30m',
#  '26h 30m',
#  '26h 30m',
#  '29h 05m',
#  '29h 05m',
# ...

# %%
pr_flight=driver.find_elements_by_xpath("//div [@class='i-b tipsy fare-summary-tooltip fs-18']")
pr_flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="cdb058f4-9b74-413f-941c-745aeba2d327")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="03666dbf-292e-4f35-809c-5e18f4ae1635")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="6f077b6d-66c4-444d-970e-e5e2a3a83b90")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3c4ba829-581f-47a6-bd4e-2fda9e2fa0f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="7a5801f1-0ffc-4672-a875-ec0c72a76958")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="34e0ac6e-48e2-424f-81a7-6e3177899dca")>,
# ...

# %%
Price=[]
for i in pr_flight:
    Price.append(i.text)
Price
# Out:
# ['1,890',
#  '1,890',
#  '1,890',
#  '1,998',
#  '1,998',
#  '1,998',
#  '1,998',
#  '1,998',
#  '2,000',
#  '2,000',
#  '2,384',
#  '2,384',
#  '2,384',
#  '2,384',
#  '2,688',
#  '2,688',
#  '2,688',
#  '2,688',
#  '2,688',
#  '2,699',
#  '4,053',
#  '4,053',
#  '4,168',
#  '4,192',
#  '4,192',
#  '4,192',
#  '4,627',
#  '4,753',
#  '4,753',
#  '4,901',
#  '4,901',
#  '4,998',
#  '5,831',
#  '5,831',
#  '5,831',
#  '5,831',
#  '5,831',
#  '5,831',
#  '5,881',
#  '5,881',
#  '5,881',
#  '5,881',
#  '5,881',
#  '5,955',
#  '6,087',
#  '6,087',
#  '6,087',
#  '6,087',
#  '6,087',
#  '6,115',
#  '6,115',
#  '6,115',
#  '6,115',
#  '6,115',
#  '6,115',
#  '6,115',
#  '6,115',
#  '6,115',
#  '6,115',
#  '6,115',
#  '6,238',
#  '6,238',
#  '7,287',
#  '7,287',
#  '7,867',
#  '7,867',
#  '7,867',
#  '7,867',
#  '7,867',
#  '7,867',
#  '7,867',
#  '7,867',
#  '7,867',
#  '7,867',
#  '7,867',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
# ...

# %%
sr_name=driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
sr_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3f086642-cb95-4c21-9191-8a3576688bb7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="59b98501-f1df-4f66-9147-1aae4201805d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="1184c285-dddb-4495-9a20-24e9ac508a74")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c5450194-b056-421a-bc34-804bcbfe3b97")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="12eb9db2-2456-40e5-b1b5-0355bc55ac5a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c1e6646c-ee35-4ba2-9b7c-3814487fb7e7")>,
# ...

# %%
Source=[]
for i in sr_name:
    Source.append(i.text)
Source
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
ds_name=driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]")
ds_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="8813acb7-5cef-48c4-8b2f-b7fe3242bdb5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="87907d13-016b-454a-8e03-8063f108f49e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9cd7c2ac-1c6c-45a2-a07d-44970864c866")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9cca899e-56da-4ddd-9b04-1ddd2d921b6d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3974eab7-2278-4f62-a9fd-b368edd47323")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9a6e4f4c-f2e2-4055-8497-19f5950ba0d0")>,
# ...

# %%
Destination=[]
for i in ds_name:
    Destination.append(i.text)
Destination
# Out:
# ['Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa']

# %%
df=pd.DataFrame({"Airline":Airline,"Arrival":Arrival,"Departure":Departure,"Duration":Duration,"Source":Source,"Destination":Destination,"Price":Price})
df
# Out:
#       Airline Arrival      Departure Duration  Source Destination   Price
# 0   Air India   05:05          06:25   1h 20m  Mumbai         Goa   1,890
# 1   Air India   13:25          14:45   1h 20m  Mumbai         Goa   1,890
# 2   Air India   21:00          22:35   1h 35m  Mumbai         Goa   1,890
# 3    Go First   05:00          06:15   1h 15m  Mumbai         Goa   1,998
# 4    Go First   11:30          12:45   1h 15m  Mumbai         Goa   1,998
# ..        ...     ...            ...      ...     ...         ...     ...
# 86    Vistara   07:30          13:50   6h 20m  Mumbai         Goa  13,398
# 87    Vistara   19:20  13:50 + 1 day  18h 30m  Mumbai         Goa  13,451
# 88    Vistara   21:00  13:50 + 1 day  16h 50m  Mumbai         Goa  18,122
# 89    Vistara   17:50  13:50 + 1 day  20h 00m  Mumbai         Goa  18,122
# 90    Vistara   17:50  13:50 + 1 day  20h 00m  Mumbai         Goa  18,122
#
# [91 rows x 7 columns]

# %%
# mum to banglore

# %%
arline_flight=driver.find_elements_by_xpath("//span [@class='i-b text ellipsis']")
arline_flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c22341e6-8eab-48d1-81ed-2795eed3285b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c62cefbe-1036-4883-81f1-49782708322b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="a688da2e-31a3-46b5-a172-7abdea8248b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="60a2249d-1425-478a-b3df-d46eaef823fe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c37d6e24-0c9c-45ba-9f2e-2f83461c273f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9d439571-26b9-475b-a8f3-a4102df09a3f")>,
# ...

# %%
Airline=[]
for i in arline_flight:
    Airline.append(i.text)
Airline
# Out:
# ['Go First',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air Asia',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
# ...

# %%
arr2_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
arr2_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="850d80d1-d3ec-46d8-8edc-c9806cb89f6f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="efa17a91-20b3-405e-bcd4-df14ad1d0415")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9237ed1c-242b-4aae-a189-c58efe5927fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="fef314ff-9a2d-4205-b88d-6f748eb328e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="f131891e-6d06-4e5d-a6d6-20636a785995")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="cc860f5e-fdf9-48bd-8b5b-07eed3e8e87c")>,
# ...

# %%
Arrival=[]
for i in arr2_time:
    Arrival.append(i.text)
Arrival
# Out:
# ['06:05',
#  '20:10',
#  '14:40',
#  '22:40',
#  '20:10',
#  '21:20',
#  '22:05',
#  '20:25',
#  '21:35',
#  '09:30',
#  '06:10',
#  '16:45',
#  '05:45',
#  '08:30',
#  '14:15',
#  '17:10',
#  '22:20',
#  '23:45',
#  '07:00',
#  '07:45',
#  '19:10',
#  '20:30',
#  '09:05',
#  '16:00',
#  '17:30',
#  '19:10',
#  '06:00',
#  '07:00',
#  '21:00',
#  '13:05',
#  '09:30',
#  '14:55',
#  '14:55',
#  '21:15',
#  '19:25',
#  '11:30',
#  '05:00',
#  '04:45',
#  '23:35',
#  '17:10',
#  '15:20',
#  '07:15',
#  '10:20',
#  '16:35',
#  '15:20',
#  '07:15',
#  '10:20',
#  '05:05',
#  '07:15',
#  '10:20',
#  '05:05',
#  '22:35',
#  '18:45',
#  '13:25',
#  '05:05',
#  '21:00',
#  '06:40',
#  '06:15',
#  '16:00',
#  '20:00',
#  '18:30',
#  '12:45',
#  '07:05',
#  '18:30',
#  '12:45',
#  '16:55',
#  '06:15',
#  '10:50',
#  '16:00',
#  '16:55',
#  '12:45',
#  '10:50',
#  '15:35',
#  '00:25',
#  '11:30',
#  '21:30',
#  '15:35',
#  '11:30',
#  '00:25',
#  '21:30',
#  '05:45',
#  '15:25',
#  '10:00',
# ...

# %%
dept_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="51f62cf6-819a-4b6d-a7e3-0abb8233075b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="86040df4-4c9c-458f-88a4-0c754cb979d4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="68a1f75c-3f75-47ee-844e-ce16cbefe8d3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d206c8a2-727b-4986-8095-5b6773b0791a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="486b7d9f-0ea5-47a8-9ecd-6d0df832ad8f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="2f295dc9-31d7-48fd-853c-94665372db86")>,
# ...

# %%
Departure=[]
for i in dept_time:
    Departure.append(i.text.replace("\n"," "))
Departure
# Out:
# ['07:45',
#  '21:55',
#  '16:30',
#  '00:30 + 1 day',
#  '22:05',
#  '23:15',
#  '00:10 + 1 day',
#  '22:10',
#  '23:40',
#  '11:10',
#  '07:55',
#  '18:30',
#  '07:20',
#  '10:15',
#  '16:00',
#  '18:55',
#  '00:05 + 1 day',
#  '01:30 + 1 day',
#  '08:50',
#  '09:35',
#  '21:05',
#  '22:25',
#  '10:45',
#  '17:45',
#  '19:15',
#  '20:55',
#  '07:50',
#  '08:50',
#  '22:50',
#  '14:45',
#  '11:15',
#  '22:25',
#  '00:05 + 1 day',
#  '22:15 + 1 day',
#  '22:15 + 1 day',
#  '15:00',
#  '15:00',
#  '08:25',
#  '08:25 + 1 day',
#  '16:00 + 1 day',
#  '20:00',
#  '12:10',
#  '15:30',
#  '22:00',
#  '22:00',
#  '14:10',
#  '17:15',
#  '12:10',
#  '15:30',
#  '18:55',
#  '09:50',
#  '06:15 + 1 day',
#  '00:45 + 1 day',
#  '22:30',
#  '22:30',
#  '22:30 + 1 day',
#  '19:55',
#  '10:40',
#  '21:00',
#  '01:00 + 1 day',
#  '23:35',
#  '18:05',
#  '13:10',
#  '01:00 + 1 day',
#  '19:25',
#  '23:35',
#  '13:10',
#  '18:05',
#  '23:35',
#  '01:00 + 1 day',
#  '21:00',
#  '19:25',
#  '22:25',
# ...

# %%
dr2_flight=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
dr2_flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="4286af21-ecf1-43b2-b5b2-184aef4ae4ec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c525c20c-e524-42af-9a5e-0154715ee46e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="aa237505-1f3c-41a6-8adb-a8ea4f812f17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="13b02a6e-55c1-4c6f-a999-1615177b1029")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="261d03b2-37de-4bcf-8c7c-4c5651805897")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="cf657a62-38c1-42b4-8ac4-99c78e27e607")>,
# ...

# %%
Duration=[]
for i in dr2_flight:
    Duration.append(i.text)
Duration
# Out:
# ['1h 40m',
#  '1h 45m',
#  '1h 50m',
#  '1h 50m',
#  '1h 55m',
#  '1h 55m',
#  '2h 05m',
#  '1h 45m',
#  '2h 05m',
#  '1h 40m',
#  '1h 45m',
#  '1h 45m',
#  '1h 35m',
#  '1h 45m',
#  '1h 45m',
#  '1h 45m',
#  '1h 45m',
#  '1h 45m',
#  '1h 50m',
#  '1h 50m',
#  '1h 55m',
#  '1h 55m',
#  '1h 40m',
#  '1h 45m',
#  '1h 45m',
#  '1h 45m',
#  '1h 50m',
#  '1h 50m',
#  '1h 50m',
#  '1h 40m',
#  '1h 45m',
#  '7h 30m',
#  '9h 10m',
#  '25h 00m',
#  '26h 50m',
#  '3h 30m',
#  '10h 00m',
#  '3h 40m',
#  '8h 50m',
#  '22h 50m',
#  '4h 40m',
#  '4h 55m',
#  '5h 10m',
#  '5h 25m',
#  '6h 40m',
#  '6h 55m',
#  '6h 55m',
#  '7h 05m',
#  '8h 15m',
#  '8h 35m',
#  '4h 45m',
#  '7h 40m',
#  '6h 00m',
#  '9h 05m',
#  '17h 25m',
#  '25h 30m',
#  '13h 15m',
#  '4h 25m',
#  '5h 00m',
#  '5h 00m',
#  '5h 05m',
#  '5h 20m',
#  '6h 05m',
#  '6h 30m',
#  '6h 40m',
#  '6h 40m',
#  '6h 55m',
#  '7h 15m',
#  '7h 35m',
#  '8h 05m',
#  '8h 15m',
#  '8h 35m',
#  '6h 50m',
#  '9h 05m',
#  '10h 55m',
#  '11h 55m',
# ...

# %%
pr2_flight=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
pr2_flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3c45d27f-63f2-4330-9d90-c7d2894ef2f1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9580fbbd-5aa2-4e8c-a0ac-2af371b1c2fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="6b49c913-116e-4458-996e-f3735ad50edb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="e506ab3f-0691-46f8-a8bb-187390d14af5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="4a2e0537-96db-4d86-af17-e3744e65132d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="636cde61-6e50-410b-b844-fbe8073bbac6")>,
# ...

# %%
Price=[]
for i in pr2_flight:
    Price.append(i.text)
Price
# Out:
# ['2,124',
#  '2,124',
#  '2,124',
#  '2,124',
#  '2,124',
#  '2,124',
#  '2,124',
#  '2,126',
#  '2,126',
#  '2,132',
#  '2,132',
#  '2,132',
#  '2,493',
#  '2,493',
#  '2,493',
#  '2,493',
#  '2,493',
#  '2,493',
#  '2,493',
#  '2,493',
#  '2,493',
#  '2,493',
#  '2,499',
#  '2,499',
#  '2,499',
#  '2,499',
#  '2,499',
#  '2,499',
#  '2,499',
#  '2,559',
#  '2,860',
#  '3,629',
#  '3,629',
#  '3,843',
#  '3,843',
#  '3,906',
#  '3,906',
#  '3,930',
#  '3,930',
#  '3,951',
#  '4,162',
#  '4,162',
#  '4,162',
#  '4,162',
#  '4,162',
#  '4,162',
#  '4,162',
#  '4,162',
#  '4,162',
#  '4,162',
#  '4,267',
#  '4,267',
#  '4,495',
#  '4,512',
#  '4,512',
#  '4,512',
#  '4,556',
#  '4,642',
#  '4,642',
#  '4,642',
#  '4,642',
#  '4,642',
#  '4,642',
#  '4,642',
#  '4,642',
#  '4,642',
#  '4,642',
#  '4,642',
#  '4,642',
#  '4,642',
#  '4,642',
#  '4,642',
#  '4,814',
#  '4,814',
#  '4,814',
#  '4,814',
#  '4,814',
#  '4,814',
#  '4,814',
#  '4,814',
#  '5,392',
#  '5,557',
#  '5,557',
# ...

# %%
sr_name=driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
sr_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="f8b179dc-941b-4f0a-b931-2ce389575321")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c27262d5-47b1-41a9-a8f4-3e6234a17a3c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="317014cb-cac8-43c5-ae7a-748e9ba0d07a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="25cb417a-aada-4c9e-a312-1c5fea433341")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="4c5baccc-d7fa-474d-a753-4b49ccd929cb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="e791e411-10ed-4f59-8645-f0792f933947")>,
# ...

# %%
Source=[]
for i in sr_name:
    Source.append(i.text)
Source
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
ds_name=driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]")
ds_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="418c23a6-ab88-4be3-a102-fd84e8eae253")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b4c9e447-9927-4ba6-a3d7-6b52f822f188")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9bde67fb-9bd4-4aae-8414-2906e6ae5413")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ecb0b444-c69f-432b-9f2f-64ca75103dcd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="62376fe3-ca67-4a42-ba6c-42f2eb8cec67")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="93e85d80-5ee7-48e7-bde4-226b7b8cc940")>,
# ...

# %%
Destination=[]
for i in ds_name:
    Destination.append(i.text)
Destination
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %%
df=pd.DataFrame({"Airline":Airline,"Arrival":Arrival,"Departure":Departure,"Duration":Duration,"Source":Source,"Destination":Destination,"Price":Price})
df
# Out:
#       Airline Arrival      Departure Duration  Source Destination   Price
# 0    Go First   06:05          07:45   1h 40m  Mumbai   Bangalore   2,124
# 1    Air Asia   20:10          21:55   1h 45m  Mumbai   Bangalore   2,124
# 2    Go First   14:40          16:30   1h 50m  Mumbai   Bangalore   2,124
# 3    Go First   22:40  00:30 + 1 day   1h 50m  Mumbai   Bangalore   2,124
# 4    Air Asia   20:10          22:05   1h 55m  Mumbai   Bangalore   2,124
# ..        ...     ...            ...      ...     ...         ...     ...
# 145   Vistara   07:30          17:05   9h 35m  Mumbai   Bangalore  10,280
# 146   Vistara   10:25          17:05   6h 40m  Mumbai   Bangalore  10,595
# 147   Vistara   10:25          18:50   8h 25m  Mumbai   Bangalore  10,595
# 148   Vistara   10:25          20:25  10h 00m  Mumbai   Bangalore  10,595
# 149   Vistara   13:20  20:25 + 1 day  31h 05m  Mumbai   Bangalore  12,797
#
# [150 rows x 7 columns]

# %%
#newdelhi to banglore

# %%
airplane_name=driver.find_elements_by_xpath("//span [@class='i-b text ellipsis']")
airplane_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="22a98d94-af46-41a3-a4c6-03d47ab90c2f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="585b811b-b68b-4878-affa-312e876cbb6d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="6d812ee1-0358-41bb-8df8-36a2d5ebfaef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9f0b0632-6827-45f4-b7fd-a881276c7436")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="1302c165-2a6f-461d-8205-c67371e181f0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b18c60b9-cfaf-4ca1-9966-d2596e7688b7")>,
# ...

# %%
Airline=[]
for i in airplane_name:
    Airline.append(i.text)
Airline
# Out:
# ['Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Air Asia',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
# ...

# %%
arrival_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
arrival_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c5849523-df16-4423-9ba8-d6e38ee8feac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="a1fe3321-0d10-4213-a89f-4ca9e2210247")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="4b203e72-b426-483d-b443-85531d666482")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="51842a33-7c94-433f-98f4-14cd31c09f75")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="57e5639d-6bd3-49d6-881a-e8e81b2676ba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3bc6a1f1-1d58-487a-a764-eb0edfad7149")>,
# ...

# %%
Arrival=[]
for i in arrival_time:
    Arrival.append(i.text)
Arrival
# Out:
# ['21:15',
#  '06:10',
#  '09:45',
#  '17:20',
#  '07:55',
#  '06:40',
#  '23:15',
#  '23:15',
#  '09:45',
#  '07:05',
#  '21:10',
#  '20:40',
#  '16:05',
#  '13:30',
#  '02:40',
#  '10:55',
#  '15:45',
#  '08:00',
#  '06:15',
#  '08:00',
#  '05:50',
#  '09:35',
#  '20:45',
#  '21:25',
#  '18:35',
#  '20:30',
#  '21:45',
#  '10:40',
#  '08:00',
#  '17:50',
#  '15:05',
#  '15:25',
#  '04:15',
#  '05:50',
#  '08:20',
#  '09:15',
#  '12:00',
#  '15:30',
#  '21:20',
#  '02:30',
#  '07:20',
#  '18:20',
#  '19:30',
#  '20:40',
#  '06:15',
#  '08:05',
#  '16:05',
#  '14:15',
#  '17:35',
#  '19:50',
#  '12:00',
#  '20:25',
#  '18:45',
#  '06:10',
#  '19:30',
#  '17:40',
#  '17:40',
#  '18:30',
#  '08:50',
#  '08:50',
#  '20:35',
#  '16:35',
#  '09:35',
#  '22:50',
#  '07:20',
#  '07:20',
#  '13:00',
#  '13:00',
#  '13:00',
#  '06:05',
#  '20:00',
#  '02:15',
#  '08:25',
#  '08:40',
#  '05:00',
#  '16:50',
#  '21:15',
#  '17:55',
#  '17:55',
#  '21:15',
#  '06:50',
#  '06:00',
#  '20:15',
# ...

# %%
departure_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
departure_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="2beedb39-8f86-4798-8e07-a8859cf39a39")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d7ea3fdb-488f-4d2d-a3c3-5bb21af530a9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ac370b76-afc0-42fb-a782-dd640af09695")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b1013b22-2204-454f-96d8-bdb1bef7eead")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="673b20f6-08a2-4539-b2a0-b3cb99091124")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="2a079aa2-5a65-408b-be21-1154f3b7cf5e")>,
# ...

# %%
Departure=[]
for i in departure_time:
    Departure.append(i.text.replace("\n"," "))
Departure
# Out:
# ['23:55',
#  '08:55',
#  '12:30',
#  '20:05',
#  '13:10',
#  '13:10',
#  '07:10 + 1 day',
#  '08:10 + 1 day',
#  '22:15',
#  '22:15',
#  '22:15 + 1 day',
#  '15:20 + 1 day',
#  '20:40',
#  '16:15',
#  '07:45',
#  '16:30',
#  '00:10 + 1 day',
#  '16:30',
#  '08:50',
#  '10:40',
#  '08:35',
#  '12:25',
#  '23:35',
#  '00:15 + 1 day',
#  '21:30',
#  '23:25',
#  '00:40 + 1 day',
#  '18:30',
#  '18:30',
#  '18:30 + 1 day',
#  '18:30 + 1 day',
#  '20:40',
#  '07:00',
#  '08:35',
#  '11:05',
#  '12:00',
#  '14:45',
#  '18:15',
#  '00:05 + 1 day',
#  '05:20',
#  '10:10',
#  '21:15',
#  '22:25',
#  '23:20',
#  '09:00',
#  '10:50',
#  '18:50',
#  '17:05',
#  '20:25',
#  '22:40',
#  '20:20',
#  '08:00 + 1 day',
#  '08:00 + 1 day',
#  '21:05',
#  '01:00 + 1 day',
#  '23:35',
#  '01:00 + 1 day',
#  '21:45 + 1 day',
#  '22:10',
#  '23:40',
#  '23:20',
#  '19:45',
#  '18:05',
#  '01:35 + 1 day',
#  '22:10',
#  '23:40',
#  '18:05',
#  '19:25',
#  '21:00',
#  '12:50',
#  '18:30 + 1 day',
#  '08:50',
# ...

# %%
duration_flight=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
duration_flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="0aac660c-0f5e-4595-972d-064d439d1d5b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="75991c89-01b2-40f1-b19f-a02357eeeecd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="a364201b-8f4c-4456-919f-20b4ed5d02ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="cec3c1a9-9d41-4019-a9dd-b69aed5d2d22")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="de5b12eb-ca84-42cb-a27a-83b1b01e9895")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="1bbb6412-d7ef-4932-8626-2bfac70fecaf")>,
# ...

# %%
Duration=[]
for i in duration_flight:
    Duration.append(i.text)
Duration
# Out:
# ['2h 40m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '5h 15m',
#  '6h 30m',
#  '7h 55m',
#  '8h 55m',
#  '12h 30m',
#  '15h 10m',
#  '25h 05m',
#  '18h 40m',
#  '4h 35m',
#  '2h 45m',
#  '5h 05m',
#  '5h 35m',
#  '8h 25m',
#  '8h 30m',
#  '2h 35m',
#  '2h 40m',
#  '2h 45m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '7h 50m',
#  '10h 30m',
#  '24h 40m',
#  '27h 25m',
#  '5h 15m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 50m',
#  '2h 50m',
#  '2h 55m',
#  '2h 55m',
#  '2h 40m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '8h 20m',
#  '11h 35m',
#  '13h 15m',
#  '14h 55m',
#  '5h 30m',
#  '5h 55m',
#  '7h 20m',
#  '27h 15m',
#  '13h 20m',
#  '14h 50m',
#  '2h 45m',
#  '3h 10m',
#  '8h 30m',
#  '2h 45m',
#  '14h 50m',
#  '16h 20m',
#  '5h 05m',
#  '6h 25m',
#  '8h 00m',
#  '6h 45m',
#  '22h 30m',
#  '6h 35m',
#  '7h 10m',
#  '8h 25m',
#  '7h 20m',
# ...

# %%
price_flight=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
price_flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9dc416cc-0f6d-45b3-82c9-5c4d243cd95b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b095c778-de89-4a40-8066-503229d9d200")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="8cdc0869-89fe-40b2-8bfa-2168c2898185")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="82bacfc0-92cf-463b-b091-e6b68f50d3f1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="a695af4b-41ae-4541-91e1-aa38ab06a081")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="66b056e0-6619-4190-9d4b-fbe4364e6d44")>,
# ...

# %%
Price=[]
for i in price_flight:
    Price.append(i.text)
Price
# Out:
# ['3,482',
#  '3,482',
#  '3,482',
#  '3,482',
#  '3,650',
#  '3,650',
#  '3,650',
#  '3,650',
#  '3,831',
#  '3,831',
#  '3,831',
#  '3,855',
#  '3,857',
#  '4,007',
#  '4,020',
#  '4,020',
#  '4,020',
#  '4,020',
#  '4,220',
#  '4,220',
#  '4,220',
#  '4,220',
#  '4,220',
#  '4,220',
#  '4,220',
#  '4,220',
#  '4,220',
#  '4,230',
#  '4,230',
#  '4,230',
#  '4,230',
#  '4,264',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,307',
#  '4,307',
#  '4,307',
#  '4,307',
#  '4,307',
#  '4,307',
#  '4,307',
#  '4,324',
#  '4,381',
#  '4,381',
#  '4,381',
#  '4,438',
#  '4,459',
#  '4,459',
#  '4,469',
#  '4,549',
#  '4,549',
#  '4,640',
#  '4,640',
#  '4,736',
#  '4,853',
#  '4,863',
#  '4,863',
#  '4,955',
#  '4,955',
#  '4,955',
#  '4,963',
#  '4,965',
#  '5,000',
#  '5,000',
#  '5,103',
#  '5,372',
#  '5,372',
#  '5,408',
#  '5,408',
#  '5,408',
#  '5,408',
#  '5,421',
#  '5,421',
#  '5,421',
# ...

# %%
sr_name=driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
sr_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="67e42bee-a242-438c-85ad-184028df6dde")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="e8a738cb-856d-440d-b902-eb167505a030")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="03a2707c-5e0b-4d07-93cb-227d3e4672a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="99825ee0-57ed-4b15-a633-36c3a4bcdcf2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="0aff4291-889a-46f6-9ade-3e8c7dcb27ac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="1ec16124-cf56-41eb-9898-6656c7943903")>,
# ...

# %%
Source=[]
for i in sr_name:
    Source.append(i.text)
Source
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
ds_name=driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]")
ds_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="39a75ab9-d1d8-49d4-aa25-0701a6e5e65a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b77a79ca-5e44-435a-bae3-d12ac5f6a2f7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="eebbda43-10db-46e2-ad55-f664803689d2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="41dfac3e-8fb3-47d3-9ed3-33b7ca90da6b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="140e16ce-c991-4e12-8021-916d783a298b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ee405509-6ec5-43ab-a5e0-ec350e00c2da")>,
# ...

# %%
Destination=[]
for i in ds_name:
    Destination.append(i.text)
Destination
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %%
df=pd.DataFrame({"Airline":Airline,"Arrival":Arrival,"Departure":Departure,"Duration":Duration,"Source":Source,"Destination":Destination,"Price":Price})
df
# Out:
#        Airline Arrival      Departure Duration     Source Destination  Price
# 0    Air India   21:15          23:55   2h 40m  New Delhi   Bangalore  3,482
# 1    Air India   06:10          08:55   2h 45m  New Delhi   Bangalore  3,482
# 2    Air India   09:45          12:30   2h 45m  New Delhi   Bangalore  3,482
# 3    Air India   17:20          20:05   2h 45m  New Delhi   Bangalore  3,482
# 4       IndiGo   07:55          13:10   5h 15m  New Delhi   Bangalore  3,650
# ..         ...     ...            ...      ...        ...         ...    ...
# 159    Vistara   07:30          19:15  11h 45m  New Delhi   Bangalore  8,181
# 160   Go First   16:45  00:15 + 1 day   7h 30m  New Delhi   Bangalore  8,197
# 161   SpiceJet   11:30          21:10   9h 40m  New Delhi   Bangalore  8,607
# 162   Air Asia   06:20          13:45   7h 25m  New Delhi   Bangalore  8,980
# 163     IndiGo   14:55          23:30   8h 35m  New Delhi   Bangalore  9,306
#
# [164 rows x 7 columns]

# %%
# banglore to Delhi

# %%
ar_name=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
ar_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="0aa593ab-3c88-424d-86b2-56833975d47d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c453b0c7-95db-43c2-b46f-bda0fcd18731")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="61359c4d-8b9e-4748-a339-cdd880483016")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="76d339b3-4d8b-4cba-8338-90ddaafa1176")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3f9b0070-99d7-45f7-8397-3d368b18a139")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ed4be594-0185-43e1-ae0c-5f35b67230eb")>,
# ...

# %%
Airline=[]
for i in ar_name:
    Airline.append(i.text)
Airline
# Out:
# ['Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
# ...

# %%
arr_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="fec67291-c045-4046-9521-32cbc7f673c6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="96260a03-766f-4978-ac8c-8b560c8683ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="51c547e3-42c9-4838-84c8-ee401eeb5f87")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3acc14f2-b47a-42c0-99dc-17215fc24dcd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="f4ecef0d-5301-4d3e-ba2e-94bf4ab1d66a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="26211af3-5570-4b40-a580-ce8a9715477a")>,
# ...

# %%
Arrival=[]
for i in arr_time:
    Arrival.append(i.text)
Arrival
# Out:
# ['13:00',
#  '07:35',
#  '07:35',
#  '07:35',
#  '20:05',
#  '18:45',
#  '12:55',
#  '18:45',
#  '16:20',
#  '16:20',
#  '10:15',
#  '16:20',
#  '18:50',
#  '18:50',
#  '18:50',
#  '08:20',
#  '16:20',
#  '05:45',
#  '16:20',
#  '08:20',
#  '10:25',
#  '06:10',
#  '13:20',
#  '17:50',
#  '21:00',
#  '18:50',
#  '23:45',
#  '21:55',
#  '06:10',
#  '11:20',
#  '00:30',
#  '00:45',
#  '22:10',
#  '05:55',
#  '09:20',
#  '21:00',
#  '07:45',
#  '23:55',
#  '06:45',
#  '08:35',
#  '08:35',
#  '06:45',
#  '08:35',
#  '06:45',
#  '06:45',
#  '19:10',
#  '19:10',
#  '19:10',
#  '19:10',
#  '19:10',
#  '08:35',
#  '11:55',
#  '14:00',
#  '16:25',
#  '04:40',
#  '06:40',
#  '09:15',
#  '17:45',
#  '19:15',
#  '20:15',
#  '23:45',
#  '07:50',
#  '21:55',
#  '17:45',
#  '21:10',
#  '07:00',
#  '08:00',
#  '11:30',
#  '19:40',
#  '09:45',
#  '19:35',
#  '08:10',
#  '06:55',
#  '18:55',
#  '06:30',
#  '07:05',
#  '06:05',
#  '12:55',
#  '20:25',
#  '17:10',
#  '11:20',
#  '05:15',
#  '20:50',
# ...

# %%
dept_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="e54bb31c-ddad-4cd0-aeed-b214c72b90af")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="0aee7e88-7969-44ec-bbaf-209310494f3b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9a890731-2049-495b-b17f-326711d1f55a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c96a6584-7bf3-4e2a-9945-ff0d48b074b9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="042980a2-ebc4-4434-9c26-e136e2781c45")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="eed0237a-37ec-423b-9619-b4bdb1d5f9ea")>,
# ...

# %%
Departure=[]
for i in dept_time:
    Departure.append(i.text.replace("\n"," "))
Departure
# Out:
# ['20:10',
#  '12:20',
#  '18:30',
#  '08:55 + 1 day',
#  '00:50 + 1 day',
#  '00:05 + 1 day',
#  '18:25',
#  '00:50 + 1 day',
#  '22:35',
#  '00:05 + 1 day',
#  '18:25',
#  '00:50 + 1 day',
#  '08:55 + 1 day',
#  '12:20 + 1 day',
#  '18:30 + 1 day',
#  '14:20',
#  '22:55',
#  '12:25',
#  '23:30',
#  '15:55',
#  '13:00',
#  '08:55',
#  '16:05',
#  '20:35',
#  '23:55',
#  '01:00 + 1 day',
#  '07:15 + 1 day',
#  '07:15 + 1 day',
#  '08:55',
#  '14:05',
#  '03:20',
#  '03:35',
#  '01:00 + 1 day',
#  '08:40',
#  '12:05',
#  '23:45',
#  '10:40',
#  '02:50 + 1 day',
#  '12:15',
#  '19:10',
#  '20:30',
#  '19:10',
#  '21:15',
#  '20:30',
#  '21:15',
#  '10:15 + 1 day',
#  '12:15 + 1 day',
#  '18:20 + 1 day',
#  '19:10 + 1 day',
#  '20:30 + 1 day',
#  '10:15 + 1 day',
#  '14:40',
#  '16:45',
#  '19:10',
#  '07:30',
#  '09:30',
#  '12:05',
#  '20:35',
#  '22:05',
#  '23:05',
#  '02:35 + 1 day',
#  '10:45',
#  '00:50 + 1 day',
#  '20:20',
#  '23:45',
#  '09:40',
#  '10:40',
#  '14:10',
# ...

# %%
dr_time=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
dr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="1bcfb66c-698a-4911-a727-ec1d6ea274c6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="cf1bf9af-7641-4b00-8e3a-f183f2bebc50")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="e144d17a-3a5a-424d-825c-de0741bd7896")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="47352bf9-04dd-4414-a392-c0390629089e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9c09b375-9745-4efc-82a6-fc6954c5bae0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="5fd41581-cfaf-4b33-ba44-bcd95d1b3b56")>,
# ...

# %%
Duration=[]
for i in dr_time:
    Duration.append(i.text)
Duration
# Out:
# ['7h 10m',
#  '4h 45m',
#  '10h 55m',
#  '25h 20m',
#  '4h 45m',
#  '5h 20m',
#  '5h 30m',
#  '6h 05m',
#  '6h 15m',
#  '7h 45m',
#  '8h 10m',
#  '8h 30m',
#  '14h 05m',
#  '17h 30m',
#  '23h 40m',
#  '6h 00m',
#  '6h 35m',
#  '6h 40m',
#  '7h 10m',
#  '7h 35m',
#  '2h 35m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 55m',
#  '6h 10m',
#  '7h 30m',
#  '9h 20m',
#  '2h 45m',
#  '2h 45m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 55m',
#  '2h 55m',
#  '5h 30m',
#  '10h 35m',
#  '11h 55m',
#  '12h 25m',
#  '12h 40m',
#  '13h 45m',
#  '14h 30m',
#  '15h 05m',
#  '17h 05m',
#  '23h 10m',
#  '24h 00m',
#  '25h 20m',
#  '25h 40m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 55m',
#  '2h 55m',
#  '2h 35m',
#  '2h 35m',
#  '2h 40m',
#  '2h 40m',
#  '2h 40m',
#  '2h 45m',
#  '2h 55m',
#  '4h 55m',
#  '16h 40m',
#  '14h 40m',
#  '14h 40m',
#  '15h 00m',
# ...

# %%
sr_name=driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
sr_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="cac68d54-1d39-4125-9182-abd9283aa095")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="95a47573-b0b0-4ee7-ad0e-14d03b3f1691")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9fd34fb4-6780-4296-b0f6-00a17c40d1a4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="967afd7d-e841-48db-bb72-38a4d7eb4b15")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ee690f41-1608-439c-93fa-7bb4dad70c1e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="105701ba-dfb8-42ec-a472-7f4f8fa175e0")>,
# ...

# %%
Source=[]
for i in sr_name:
    Source.append(i.text)
Source
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %%
ds_name=driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]")
ds_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="746271de-57cd-40a9-a27e-cdde5d89600f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3ea32be1-af1c-44e7-9f72-491b93c65375")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ab281860-35e3-47a1-ba86-7c5044d13a92")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="04288bd0-5e64-4efc-907e-d1c3a980f7c1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="7367f86f-5c3e-4e85-b16a-e0c84b9d8faa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c3a38031-b2c5-4b5d-8bdd-56d13b9ac774")>,
# ...

# %%
Destination=[]
for i in ds_name:
    Destination.append(i.text)
Destination
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
pr_amt=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
pr_amt
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="436257ca-8ca3-44af-866f-9480c66e0bf7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="4f99e0a6-9b31-4109-82d5-46361962afe2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="e81ae100-c077-41b0-8064-9f3f7c838227")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="de0d745a-1e07-4d25-854e-6d02bb044748")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="8b2082b6-abba-4262-a9a4-ff6f41d7070b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="0e4ee2fc-e066-43b8-9027-b520af15438d")>,
# ...

# %%
Price=[]
for i in pr_amt:
    Price.append(i.text)
Price
# Out:
# ['3,525',
#  '3,674',
#  '3,674',
#  '3,674',
#  '3,818',
#  '3,818',
#  '3,818',
#  '3,818',
#  '3,818',
#  '3,818',
#  '3,818',
#  '3,818',
#  '3,895',
#  '3,895',
#  '3,895',
#  '4,028',
#  '4,028',
#  '4,028',
#  '4,028',
#  '4,028',
#  '4,071',
#  '4,071',
#  '4,071',
#  '4,071',
#  '4,071',
#  '4,081',
#  '4,156',
#  '4,156',
#  '4,283',
#  '4,283',
#  '4,283',
#  '4,283',
#  '4,283',
#  '4,284',
#  '4,284',
#  '4,284',
#  '4,284',
#  '4,284',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,294',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,300',
#  '4,308',
#  '4,308',
#  '4,308',
#  '4,308',
#  '4,308',
#  '4,308',
#  '4,308',
#  '4,338',
#  '4,442',
#  '4,607',
#  '4,618',
#  '4,618',
#  '4,627',
#  '4,627',
#  '4,627',
#  '4,704',
#  '4,748',
#  '4,748',
#  '4,748',
#  '4,756',
# ...

# %%
df=pd.DataFrame({"Airline":Airline,"Arrival":Arrival,"Departure":Departure,"Duration":Duration,"Source":Source,"Destination":Destination,"Price":Price})
df
# Out:
#        Airline Arrival      Departure Duration     Source Destination   Price
# 0     Air Asia   13:00          20:10   7h 10m  Bangalore   New Delhi   3,525
# 1    Air India   07:35          12:20   4h 45m  Bangalore   New Delhi   3,674
# 2    Air India   07:35          18:30  10h 55m  Bangalore   New Delhi   3,674
# 3    Air India   07:35  08:55 + 1 day  25h 20m  Bangalore   New Delhi   3,674
# 4       IndiGo   20:05  00:50 + 1 day   4h 45m  Bangalore   New Delhi   3,818
# ..         ...     ...            ...      ...        ...         ...     ...
# 156   SpiceJet   15:40          20:25   4h 45m  Bangalore   New Delhi   8,642
# 157    Vistara   06:40          12:40   6h 00m  Bangalore   New Delhi   8,900
# 158   Air Asia   11:45          19:20   7h 35m  Bangalore   New Delhi   9,178
# 159   SpiceJet   12:30          19:10   6h 40m  Bangalore   New Delhi   9,902
# 160   Go First   15:45          20:10   4h 25m  Bangalore   New Delhi  10,680
#
# [161 rows x 7 columns]

# %%
#bom to kolkata

# %%
ar_name=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
ar_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="73878716-d328-4631-9c09-faed5d2ddcc0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="1aa92092-9cad-48ce-a817-0f1d3b5178ec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="be52b6e9-f23a-4653-b0c1-dc351cb02f30")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="df5c6036-d01c-4b55-a3ac-0efea2609a7e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="bb043401-92b6-44bb-9909-af3f9a3f54ae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c1d1e524-5685-4943-9b84-9b454aac7347")>,
# ...

# %%
Airline=[]
for i in ar_name:
    Airline.append(i.text)
Airline
# Out:
# ['Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'SpiceJet',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
# ...

# %%
arr_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d3cc9726-675b-4756-b181-5b9cc8562910")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="59a70a63-0bed-421a-9966-4303b2a124d4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c1fe8482-56d0-4b50-94b3-ce82267016c5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b4a7286f-df2c-4bd0-a4d3-fc61be4705da")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3f3d9a05-1e3c-498e-bdd2-aecf651be3bd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="4facbbf1-156c-4db5-a87e-61ed96ba85a3")>,
# ...

# %%
Arrival=[]
for i in arr_time:
    Arrival.append(i.text)
Arrival
# Out:
# ['20:30',
#  '06:10',
#  '21:15',
#  '19:25',
#  '21:15',
#  '19:25',
#  '05:20',
#  '22:55',
#  '07:20',
#  '05:00',
#  '14:30',
#  '21:00',
#  '08:00',
#  '15:25',
#  '07:05',
#  '10:00',
#  '19:00',
#  '08:00',
#  '18:00',
#  '07:05',
#  '15:25',
#  '19:00',
#  '18:00',
#  '10:00',
#  '15:25',
#  '19:00',
#  '08:00',
#  '18:00',
#  '07:05',
#  '19:00',
#  '15:25',
#  '18:00',
#  '10:00',
#  '09:50',
#  '09:50',
#  '16:15',
#  '10:45',
#  '09:50',
#  '16:25',
#  '21:30',
#  '14:40',
#  '06:05',
#  '10:00',
#  '08:00',
#  '07:05',
#  '20:10',
#  '20:10',
#  '21:20',
#  '06:10',
#  '16:45',
#  '09:30',
#  '06:10',
#  '05:50',
#  '20:00',
#  '13:05',
#  '13:05',
#  '13:05',
#  '21:35',
#  '20:25',
#  '19:55',
#  '22:30',
#  '15:25',
#  '19:00',
#  '19:00',
#  '18:00',
#  '18:00',
#  '10:00',
#  '08:00',
#  '17:45',
#  '17:45',
#  '17:45',
#  '16:55',
#  '07:05',
#  '12:45',
#  '16:00',
#  '06:15',
#  '10:50',
#  '20:00',
#  '12:45',
#  '18:30',
#  '21:05',
#  '06:30',
#  '07:40',
# ...

# %%
dept_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="2209e874-1196-4060-b74d-55b22033cfb5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="1989928f-9f50-44ef-892a-e3b5025c0230")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="1b9cf8ad-bba7-4c40-b947-3f363f074a82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="0de844a6-58b2-463b-aece-03a093854f8b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="03c7a18d-82e8-431e-85c2-1ae337bebc93")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="6ed463f5-a55a-4572-96ec-5d435469ffdb")>,
# ...

# %%
Departure=[]
for i in dept_time:
    Departure.append(i.text.replace("\n"," "))
Departure
# Out:
# ['23:15',
#  '08:50',
#  '08:05 + 1 day',
#  '08:05 + 1 day',
#  '16:00 + 1 day',
#  '16:00 + 1 day',
#  '13:55',
#  '07:10 + 1 day',
#  '19:15',
#  '07:30',
#  '17:20',
#  '23:50',
#  '14:30',
#  '22:20',
#  '14:30',
#  '22:20',
#  '09:00 + 1 day',
#  '22:20',
#  '09:00 + 1 day',
#  '22:20',
#  '09:00 + 1 day',
#  '14:30 + 1 day',
#  '14:30 + 1 day',
#  '09:00 + 1 day',
#  '14:30 + 1 day',
#  '19:10 + 1 day',
#  '09:00 + 1 day',
#  '19:10 + 1 day',
#  '09:00 + 1 day',
#  '22:20 + 1 day',
#  '19:10 + 1 day',
#  '22:20 + 1 day',
#  '14:30 + 1 day',
#  '17:30',
#  '20:15',
#  '21:35',
#  '21:35',
#  '14:35',
#  '23:00',
#  '07:35 + 1 day',
#  '22:20',
#  '16:30',
#  '19:10',
#  '19:10',
#  '19:10',
#  '01:35 + 1 day',
#  '01:35 + 1 day',
#  '09:00 + 1 day',
#  '13:30',
#  '08:20 + 1 day',
#  '08:20 + 1 day',
#  '08:20 + 1 day',
#  '08:35',
#  '07:50 + 1 day',
#  '19:45',
#  '21:05',
#  '01:35 + 1 day',
#  '08:25 + 1 day',
#  '08:25 + 1 day',
#  '22:30',
#  '08:35 + 1 day',
# ...

# %%
dur_time=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
dur_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="71f06437-6482-4787-8235-3a0b1ddccbb0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b7177874-b262-4656-b0a8-f37eee960df7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="4bd7ead4-083e-4dfb-91a7-6edc78177295")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="7f8a216c-5c73-4e29-8bda-3b7217037fb7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d9103747-6b8c-4d0e-939c-a5c389512b2e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="a1583eac-3935-4488-81f5-e8786ebb1a7e")>,
# ...

# %%
Duration=[]
for i in dur_time:
    Duration.append(i.text)
Duration
# Out:
# ['2h 45m',
#  '2h 40m',
#  '10h 50m',
#  '12h 40m',
#  '18h 45m',
#  '20h 35m',
#  '8h 35m',
#  '8h 15m',
#  '11h 55m',
#  '2h 30m',
#  '2h 50m',
#  '2h 50m',
#  '6h 30m',
#  '6h 55m',
#  '7h 25m',
#  '12h 20m',
#  '14h 00m',
#  '14h 20m',
#  '15h 00m',
#  '15h 15m',
#  '17h 35m',
#  '19h 30m',
#  '20h 30m',
#  '23h 00m',
#  '23h 05m',
#  '24h 10m',
#  '25h 00m',
#  '25h 10m',
#  '25h 55m',
#  '27h 20m',
#  '27h 45m',
#  '28h 20m',
#  '28h 30m',
#  '7h 40m',
#  '10h 25m',
#  '5h 20m',
#  '10h 50m',
#  '4h 45m',
#  '6h 35m',
#  '10h 05m',
#  '7h 40m',
#  '10h 25m',
#  '9h 10m',
#  '11h 10m',
#  '12h 05m',
#  '5h 25m',
#  '5h 25m',
#  '11h 40m',
#  '7h 20m',
#  '15h 35m',
#  '22h 50m',
#  '26h 10m',
#  '2h 45m',
#  '11h 50m',
#  '6h 40m',
#  '8h 00m',
#  '12h 30m',
#  '10h 50m',
#  '12h 00m',
#  '2h 35m',
#  '10h 05m',
#  '16h 40m',
#  '21h 00m',
#  '21h 00m',
#  '22h 00m',
#  '22h 00m',
#  '22h 05m',
#  '24h 05m',
#  '15h 15m',
#  '20h 45m',
#  '25h 25m',
#  '6h 00m',
#  '6h 15m',
# ...

# %%
sr_name=driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
sr_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3c14a22b-0ddc-4a37-bb12-002952449156")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="13aa9b49-a0cc-4266-8ecc-647a9ab8a7c2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="6c4f46a6-308e-4c3d-a022-bd06c4f9a5e8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c9547e68-92e4-4c71-9d51-06b4beaa407c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="93907e2a-b102-44f0-9833-00f85351e665")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="6746a6f4-d086-4d99-af3a-793897c45756")>,
# ...

# %%
Source=[]
for i in sr_name:
    Source.append(i.text)
Source
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
dst_name=driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]")
dst_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9072ac73-e031-48eb-b4af-b8ce0bd9ab3a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c68e0b9c-358c-4217-8bc0-1a034adce745")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c299b872-42bc-45e7-9931-7ad3e3233cdc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="caca135d-91b9-4ac9-99c3-26c4e4afa679")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="75c549c2-0015-4809-992c-45e52a20ae03")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b52df9df-ab8a-4b89-90fc-fa7c6347c304")>,
# ...

# %%
Destination=[]
for i in dst_name:
    Destination.append(i.text)
Destination
# Out:
# ['Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
# ...

# %%
pr=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
pr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="1aa9d4f1-6936-4dcd-9750-c6cb0ec54081")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="481e7d58-384e-4f36-988a-ee03db7b2b88")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="4fad7046-d76a-46b0-baae-61c284dbe601")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d301e805-40e6-4d9c-9ad9-59a0e73e1104")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="e2ac2e84-2e79-4c6d-990c-f62e57b2eeaf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="48d65001-0770-481a-bf59-9f2cd449beec")>,
# ...

# %%
Price=[]
for i in pr:
    Price.append(i.text)
Price
# Out:
# ['2,835',
#  '3,177',
#  '3,623',
#  '3,623',
#  '3,623',
#  '3,623',
#  '3,932',
#  '4,351',
#  '4,351',
#  '4,500',
#  '4,500',
#  '4,500',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,556',
#  '4,774',
#  '4,774',
#  '4,886',
#  '4,886',
#  '4,957',
#  '4,957',
#  '4,957',
#  '4,961',
#  '4,961',
#  '4,977',
#  '4,977',
#  '4,977',
#  '4,985',
#  '4,985',
#  '4,985',
#  '5,070',
#  '5,070',
#  '5,070',
#  '5,070',
#  '5,097',
#  '5,167',
#  '5,420',
#  '5,420',
#  '5,420',
#  '5,481',
#  '5,481',
#  '5,517',
#  '5,652',
#  '5,685',
#  '5,685',
#  '5,685',
#  '5,685',
#  '5,685',
#  '5,685',
#  '5,685',
#  '5,756',
#  '5,756',
#  '5,756',
#  '5,902',
#  '5,902',
#  '5,902',
#  '5,902',
#  '5,902',
#  '5,902',
#  '5,902',
#  '5,902',
#  '5,902',
#  '5,912',
#  '5,912',
#  '5,912',
# ...

# %%
df=pd.DataFrame({"Airline":Airline,"Arrival":Arrival,"Departure":Departure,"Duration":Duration,"Source":Source,"Destination":Destination,"Price":Price})
df
# Out:
#        Airline Arrival      Departure Duration  Source Destination   Price
# 0    Air India   20:30          23:15   2h 45m  Mumbai     Kolkata   2,835
# 1    Air India   06:10          08:50   2h 40m  Mumbai     Kolkata   3,177
# 2    Air India   21:15  08:05 + 1 day  10h 50m  Mumbai     Kolkata   3,623
# 3    Air India   19:25  08:05 + 1 day  12h 40m  Mumbai     Kolkata   3,623
# 4    Air India   21:15  16:00 + 1 day  18h 45m  Mumbai     Kolkata   3,623
# ..         ...     ...            ...      ...     ...         ...     ...
# 137     IndiGo   12:20          22:45  10h 25m  Mumbai     Kolkata  11,017
# 138   SpiceJet   07:20          20:30  13h 10m  Mumbai     Kolkata  11,237
# 139   SpiceJet   10:25          20:40  10h 15m  Mumbai     Kolkata  11,433
# 140   SpiceJet   10:15          20:30  10h 15m  Mumbai     Kolkata  11,553
# 141   SpiceJet   12:40  10:40 + 1 day  22h 00m  Mumbai     Kolkata  17,530
#
# [142 rows x 7 columns]

# %%
#kol to bom

# %%
ar_name=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
ar_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="a9fae492-ba95-43eb-9ffe-0b751b61ff55")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="4fd474b1-5ece-4a59-97e7-b9a16402a096")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="53e212e0-d476-4312-9a65-5c16ce13704e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c4c7fbcb-f3eb-4d91-9535-8c0be47f89d2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="8dcaab9d-0bad-4b06-8f57-39cfce0a84fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="f6bf0de5-da6f-4d53-acb5-cab469769ba4")>,
# ...

# %%
Airline=[]
for i in ar_name:
    Airline.append(i.text)
Airline
# Out:
# ['Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'SpiceJet',
#  'SpiceJet',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Air India',
# ...

# %%
arr=driver.find_elements_by_xpath("//div[@class='i-b pr']")
arr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ec85281f-23c7-42c3-8a61-53970b3ccc1e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="1d44bdd9-9cf9-4500-8bbe-d7ed7bf001b7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="e88ef56a-cfb4-4f6d-ba8c-5a478b899540")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="1dbd48e6-7cb2-43c0-928f-b7bfc89ca4e6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ff207a25-7a0d-4677-bf9e-f61feeadd26e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="93b9e4c0-0142-4313-a3f5-a4e02084ba80")>,
# ...

# %%
Arrival=[]
for i in arr:
    Arrival.append(i.text)
Arrival
# Out:
# ['09:25',
#  '16:55',
#  '19:00',
#  '14:40',
#  '14:40',
#  '04:55',
#  '17:30',
#  '17:50',
#  '23:40',
#  '10:25',
#  '10:25',
#  '06:55',
#  '20:30',
#  '06:55',
#  '15:30',
#  '20:30',
#  '10:25',
#  '20:30',
#  '20:30',
#  '20:30',
#  '15:30',
#  '06:55',
#  '15:30',
#  '18:00',
#  '07:45',
#  '19:45',
#  '15:20',
#  '06:25',
#  '09:30',
#  '13:30',
#  '16:15',
#  '16:15',
#  '21:35',
#  '09:40',
#  '13:30',
#  '13:30',
#  '07:00',
#  '14:10',
#  '11:35',
#  '14:00',
#  '06:50',
#  '23:35',
#  '14:00',
#  '09:15',
#  '23:35',
#  '14:00',
#  '06:50',
#  '20:10',
#  '09:15',
#  '23:35',
#  '20:10',
#  '09:15',
#  '10:10',
#  '16:45',
#  '16:45',
#  '15:30',
#  '10:25',
#  '06:55',
#  '21:30',
#  '05:45',
#  '05:45',
#  '05:45',
#  '09:10',
#  '06:55',
#  '19:00',
#  '19:00',
#  '19:00',
#  '19:00',
#  '19:00',
#  '19:00',
#  '19:00',
#  '19:00',
#  '19:00',
#  '10:25',
#  '06:55',
#  '20:30',
#  '17:40',
#  '11:25',
#  '07:00',
#  '07:35',
#  '04:00',
#  '07:10',
#  '09:00',
# ...

# %%
dept=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
dept
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="5a42070f-46c4-4817-a7e2-fc9d175fa308")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ec616355-4a7a-4410-af22-77f86af4b6c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="894cae83-be9f-4c03-b053-7f25b4da1834")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="1ff76fad-6fa2-42ee-b5a3-7f30391bfbc4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="39280c6a-9f04-45b3-b15b-a934bff59642")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d1b6eb6a-6a86-4ec8-836c-1ccdb28975ec")>,
# ...

# %%
Departure=[]
for i in dept:
    Departure.append(i.text.replace("\n"," "))
Departure
# Out:
# ['12:25',
#  '20:30',
#  '09:40 + 1 day',
#  '08:05 + 1 day',
#  '17:05 + 1 day',
#  '07:45',
#  '20:20',
#  '08:10 + 1 day',
#  '06:35 + 1 day',
#  '18:15',
#  '21:35',
#  '18:15',
#  '10:10 + 1 day',
#  '21:35',
#  '10:10 + 1 day',
#  '18:15 + 1 day',
#  '10:10 + 1 day',
#  '21:15 + 1 day',
#  '21:35 + 1 day',
#  '22:10 + 1 day',
#  '18:15 + 1 day',
#  '10:10 + 1 day',
#  '21:35 + 1 day',
#  '20:45',
#  '10:35',
#  '06:35 + 1 day',
#  '21:40',
#  '15:00',
#  '18:15',
#  '20:35',
#  '00:35 + 1 day',
#  '00:35 + 1 day',
#  '07:15 + 1 day',
#  '20:35',
#  '00:35 + 1 day',
#  '00:35 + 1 day',
#  '16:30',
#  '21:05',
#  '17:10',
#  '19:20',
#  '12:25',
#  '05:55 + 1 day',
#  '20:50',
#  '16:35',
#  '07:40 + 1 day',
#  '23:25',
#  '16:35',
#  '05:55 + 1 day',
#  '19:20',
#  '10:10 + 1 day',
#  '07:40 + 1 day',
#  '20:50',
#  '23:50',
#  '00:15 + 1 day',
#  '07:25 + 1 day',
#  '22:10',
#  '22:10',
#  '22:10',
#  '08:15 + 1 day',
#  '13:10',
#  '16:40',
#  '18:00',
#  '12:00',
#  '15:50',
# ...

# %%
sr=driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
sr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="2d769b8c-d3f3-4290-af11-a683fff9c72b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="a4eaecab-7481-4bdc-9e94-09423857fa0d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b7ba3da3-56ed-47c8-b530-d4cdf273a628")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="4d3b9a58-af47-4151-846b-4df1e6259cc5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="6161771b-3a40-4e58-89ff-a6eef9d19869")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d3d71a9c-c28b-4fad-989c-203dbbd5dc07")>,
# ...

# %%
Source=[]
for i in sr:
    Source.append(i.text)
Source
# Out:
# ['Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
# ...

# %%
dst=driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]")
dst
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="772fb887-04cb-4bbb-86dd-ceaf3862be81")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="094d857b-e001-4845-b9d6-2ce81310165e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="0f9ac19c-a54d-4520-a62c-f6d7230304eb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="cf96706a-c6a3-4ff7-b621-4763e3610370")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ae0e6208-a21b-4b72-9a87-40aa5a4c471a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="660d66a8-123e-43f8-9d34-f1d151a8d3af")>,
# ...

# %%
Destination=[]
for i in dst:
    Destination.append(i.text)
Destination
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
pr=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
pr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d38cb0d3-cf64-47ef-a43a-20c0744c1bfc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="83dcc626-18f8-4868-b196-a67a9af33e39")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="626e53b5-f2b5-48f2-b97a-efb5b0729dc6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9c278a5d-d04d-4989-a6ae-7036e4a59cb4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="86124c18-446d-4268-ae5b-3fa563a15a78")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="060a432d-7e3c-4090-a61f-3954077e8934")>,
# ...

# %%
Price=[]
for i in pr:
    Price.append(i.text)
Price
# Out:
# ['3,381',
#  '3,381',
#  '4,169',
#  '4,478',
#  '4,478',
#  '4,499',
#  '4,499',
#  '4,933',
#  '4,956',
#  '5,102',
#  '5,102',
#  '5,102',
#  '5,102',
#  '5,102',
#  '5,102',
#  '5,102',
#  '5,102',
#  '5,102',
#  '5,102',
#  '5,102',
#  '5,102',
#  '5,102',
#  '5,102',
#  '5,333',
#  '5,333',
#  '5,353',
#  '5,503',
#  '5,503',
#  '5,507',
#  '5,531',
#  '5,531',
#  '5,531',
#  '5,531',
#  '5,531',
#  '5,531',
#  '5,531',
#  '5,607',
#  '5,616',
#  '5,644',
#  '5,708',
#  '5,708',
#  '5,708',
#  '5,708',
#  '5,708',
#  '5,708',
#  '5,708',
#  '5,708',
#  '5,708',
#  '5,708',
#  '5,708',
#  '5,708',
#  '5,708',
#  '5,763',
#  '5,790',
#  '5,790',
#  '5,837',
#  '5,837',
#  '5,837',
#  '6,107',
#  '6,135',
#  '6,135',
#  '6,135',
#  '6,173',
#  '6,179',
#  '6,231',
#  '6,231',
#  '6,231',
#  '6,231',
#  '6,231',
#  '6,231',
#  '6,231',
#  '6,231',
#  '6,231',
#  '6,302',
#  '6,302',
#  '6,302',
#  '6,311',
#  '6,377',
#  '6,377',
#  '6,421',
#  '6,458',
#  '6,458',
#  '6,458',
# ...

# %%
drr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
drr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="a7cb8e2e-e6e2-4c81-8356-cdf8ce508780")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b563ef1b-ceb2-470f-a3ab-1bca4292490c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="89981aec-f816-4d68-84b3-5a081411a0e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="0ef444ca-fa0e-4b30-a15c-bb8eef394b9f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="4e6506c4-04f0-493a-984b-6c200e4dba87")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="922a84af-3bdf-417d-8558-280abe36e382")>,
# ...

# %%
Duration=[]
for i in drr:
    Duration.append(i.text)
Duration
# Out:
# ['3h 00m',
#  '3h 35m',
#  '14h 40m',
#  '17h 25m',
#  '26h 25m',
#  '2h 50m',
#  '2h 50m',
#  '14h 20m',
#  '6h 55m',
#  '7h 50m',
#  '11h 10m',
#  '11h 20m',
#  '13h 40m',
#  '14h 40m',
#  '18h 40m',
#  '21h 45m',
#  '23h 45m',
#  '24h 45m',
#  '25h 05m',
#  '25h 40m',
#  '26h 45m',
#  '27h 15m',
#  '30h 05m',
#  '2h 45m',
#  '2h 50m',
#  '10h 50m',
#  '6h 20m',
#  '8h 35m',
#  '8h 45m',
#  '7h 05m',
#  '8h 20m',
#  '8h 20m',
#  '9h 40m',
#  '10h 55m',
#  '11h 05m',
#  '11h 05m',
#  '9h 30m',
#  '6h 55m',
#  '5h 35m',
#  '5h 20m',
#  '5h 35m',
#  '6h 20m',
#  '6h 50m',
#  '7h 20m',
#  '8h 05m',
#  '9h 25m',
#  '9h 45m',
#  '9h 45m',
#  '10h 05m',
#  '10h 35m',
#  '11h 30m',
#  '11h 35m',
#  '13h 40m',
#  '7h 30m',
#  '14h 40m',
#  '6h 40m',
#  '11h 45m',
#  '15h 15m',
#  '10h 45m',
#  '7h 25m',
#  '10h 55m',
#  '12h 15m',
#  '2h 50m',
#  '8h 55m',
#  '23h 15m',
#  '23h 15m',
#  '26h 15m',
#  '26h 15m',
#  '26h 35m',
#  '26h 35m',
#  '27h 10m',
#  '27h 10m',
#  '27h 10m',
# ...

# %%
df=pd.DataFrame({"Airline":Airline,"Arrival":Arrival,"Departure":Departure,"Duration":Duration,"Source":Source,"Destination":Destination,"Price":Price})
df
# Out:
#        Airline Arrival      Departure Duration   Source Destination   Price
# 0    Air India   09:25          12:25   3h 00m  Kolkata      Mumbai   3,381
# 1    Air India   16:55          20:30   3h 35m  Kolkata      Mumbai   3,381
# 2    Air India   19:00  09:40 + 1 day  14h 40m  Kolkata      Mumbai   4,169
# 3    Air India   14:40  08:05 + 1 day  17h 25m  Kolkata      Mumbai   4,478
# 4    Air India   14:40  17:05 + 1 day  26h 25m  Kolkata      Mumbai   4,478
# ..         ...     ...            ...      ...      ...         ...     ...
# 129   SpiceJet   18:00  09:35 + 1 day  15h 35m  Kolkata      Mumbai  10,719
# 130   SpiceJet   06:20          22:05  15h 45m  Kolkata      Mumbai  11,243
# 131   SpiceJet   06:20          21:05  14h 45m  Kolkata      Mumbai  11,559
# 132   Go First   16:40          21:10   4h 30m  Kolkata      Mumbai  12,133
# 133   SpiceJet   06:50          19:10  12h 20m  Kolkata      Mumbai  16,409
#
# [134 rows x 7 columns]

# %%
#bom to chennai

# %%
ar=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
ar
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c6ce440d-697c-4140-9a51-66fa6cf171b8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="4000af07-5c15-47dc-810f-e082abba83d1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3547a93c-ec42-4a79-a5f9-3212752ed6ce")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ca452477-d4da-47ef-9935-337ad1fd0310")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="0e90e29a-5188-409f-8598-03c2f26688c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b37dace7-f34c-4fc5-9719-e297412d1e2a")>,
# ...

# %%
Airline=[]
for i in ar:
    Airline.append(i.text)
Airline
# Out:
# ['Air India',
#  'Air India',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
# ...

# %%
arr=driver.find_elements_by_xpath("//div[@class='i-b pr']")
arr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="146ef060-7835-4cb3-a8e2-40da97147b7f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="82dd0034-abf1-40e1-9621-ff530494d673")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="53e3c275-d95e-4154-abc9-af515cf0952e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="780cf250-50d9-4767-b313-c88da8df33ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="944f70cd-3bf2-4202-8734-6cf9ebe75268")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="7ef08396-66e1-4844-b326-03b0f1de96da")>,
# ...

# %%
Arrival=[]
for i in arr:
    Arrival.append(i.text)
Arrival
# Out:
# ['05:20',
#  '09:00',
#  '19:55',
#  '05:50',
#  '18:40',
#  '05:05',
#  '16:35',
#  '07:15',
#  '10:20',
#  '15:20',
#  '19:10',
#  '21:25',
#  '22:35',
#  '06:45',
#  '09:45',
#  '17:50',
#  '21:00',
#  '21:15',
#  '19:25',
#  '21:20',
#  '20:10',
#  '20:10',
#  '21:15',
#  '16:45',
#  '21:35',
#  '20:25',
#  '21:35',
#  '20:25',
#  '13:05',
#  '13:05',
#  '15:25',
#  '10:00',
#  '19:00',
#  '18:00',
#  '08:00',
#  '07:05',
#  '15:25',
#  '19:00',
#  '18:00',
#  '15:25',
#  '10:00',
#  '08:00',
#  '12:30',
#  '08:20',
#  '07:05',
#  '10:50',
#  '20:00',
#  '12:45',
#  '06:15',
#  '16:55',
#  '18:30',
#  '16:00',
#  '12:45',
#  '10:50',
#  '16:55',
#  '07:05',
#  '10:50',
#  '16:00',
#  '06:15',
#  '12:45',
#  '20:00',
#  '07:05',
#  '16:00',
#  '12:45',
#  '10:50',
#  '06:10',
#  '20:30',
#  '15:25',
#  '07:55',
#  '20:30',
#  '13:35',
#  '13:35',
#  '11:30',
#  '19:20',
#  '13:30',
#  '17:20',
#  '06:00',
#  '08:20',
#  '19:00',
#  '18:00',
#  '15:25',
#  '15:25',
#  '10:00',
# ...

# %%
depart=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
depart
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="28cb656e-31e7-4d76-a695-6cba5a4d9862")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c111a21a-5fcc-4837-b403-2de121ed01f5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="5a21f5d6-205d-465e-9368-99b2d81acbf8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="48e8a4f0-9fad-4583-b386-3cfba6967f88")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="2c35ccff-6884-4be5-a11e-9130be624c6e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="0c535389-8f94-49d0-884b-19a97268c7c3")>,
# ...

# %%
Departure=[]
for i in depart:
    Departure.append(i.text)
Departure
# Out:
# ['07:15',
#  '10:55',
#  '21:45',
#  '07:45',
#  '20:40',
#  '07:00',
#  '18:30',
#  '09:15',
#  '12:25',
#  '17:25',
#  '21:15',
#  '23:30',
#  '00:40\n+ 1 day',
#  '08:50',
#  '11:50',
#  '19:55',
#  '23:05',
#  '08:00\n+ 1 day',
#  '08:00\n+ 1 day',
#  '08:30\n+ 1 day',
#  '08:30\n+ 1 day',
#  '08:30\n+ 1 day',
#  '22:35\n+ 1 day',
#  '12:50\n+ 1 day',
#  '09:10\n+ 1 day',
#  '09:10\n+ 1 day',
#  '21:40\n+ 1 day',
#  '21:40\n+ 1 day',
#  '16:30',
#  '17:25',
#  '23:35',
#  '23:35',
#  '08:55\n+ 1 day',
#  '08:55\n+ 1 day',
#  '23:35',
#  '23:35',
#  '08:55\n+ 1 day',
#  '12:40\n+ 1 day',
#  '12:40\n+ 1 day',
#  '12:40\n+ 1 day',
#  '08:55\n+ 1 day',
#  '08:55\n+ 1 day',
#  '19:30',
#  '19:30',
#  '11:20',
#  '15:10',
#  '00:25\n+ 1 day',
#  '17:30',
#  '11:20',
#  '22:05',
#  '00:25\n+ 1 day',
#  '22:05',
#  '18:55',
#  '17:30',
#  '00:25\n+ 1 day',
#  '15:10',
#  '18:55',
#  '00:25\n+ 1 day',
#  '15:10',
#  '22:05',
#  '05:55\n+ 1 day',
#  '17:30',
#  '20:20',
#  '20:20',
# ...

# %%
dur=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
dur
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="60a7986c-df0a-4557-8092-3beb7844dcfd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="f4f146c7-1702-424d-a89a-f78b0f6735fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="aabd6710-de60-4b9d-973b-9ca066eb1ff2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="a8ef6b90-5c7b-48e2-80f7-5d3e36a77eed")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="7c02d496-d359-48b5-8b0c-59577c7322aa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ba4f649e-ba11-43df-83a9-7c315c06b2cf")>,
# ...

# %%
Duration=[]
for i in dur:
    Duration.append(i.text)
Duration
# Out:
# ['1h 55m',
#  '1h 55m',
#  '1h 50m',
#  '1h 55m',
#  '2h 00m',
#  '1h 55m',
#  '1h 55m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '10h 45m',
#  '12h 35m',
#  '11h 10m',
#  '12h 20m',
#  '12h 20m',
#  '25h 20m',
#  '20h 05m',
#  '11h 35m',
#  '12h 45m',
#  '24h 05m',
#  '25h 15m',
#  '3h 25m',
#  '4h 20m',
#  '8h 10m',
#  '13h 35m',
#  '13h 55m',
#  '14h 55m',
#  '15h 35m',
#  '16h 30m',
#  '17h 30m',
#  '17h 40m',
#  '18h 40m',
#  '21h 15m',
#  '22h 55m',
#  '24h 55m',
#  '7h 00m',
#  '11h 10m',
#  '4h 15m',
#  '4h 20m',
#  '4h 25m',
#  '4h 45m',
#  '5h 05m',
#  '5h 10m',
#  '5h 55m',
#  '6h 05m',
#  '6h 10m',
#  '6h 40m',
#  '7h 30m',
#  '8h 05m',
#  '8h 05m',
#  '8h 25m',
#  '8h 55m',
#  '9h 20m',
#  '9h 55m',
#  '10h 25m',
#  '4h 20m',
#  '7h 35m',
#  '9h 30m',
#  '10h 55m',
#  '20h 35m',
#  '16h 35m',
#  '14h 55m',
#  '26h 05m',
#  '5h 35m',
#  '9h 25m',
#  '10h 40m',
#  '5h 40m',
# ...

# %%
sr=driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
sr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="bf7be286-6b9b-4a21-9903-6851d1ab8497")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c058d43b-c38c-400a-9f3f-4b9ab29064bc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="a04a04a1-f1e4-4990-869d-a8f9bc596bae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="208d0e65-10f4-4a37-bcd3-28c4537f21c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d1946f72-8357-4198-b6f1-cc84945287fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3cb9bce6-863a-4fee-8140-8cdc3c1cf2c9")>,
# ...

# %%
Source=[]
for i in sr:
    Source.append(i.text)
Source
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
dst=driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]")
dst
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="7791d035-dd3b-473a-851a-90360d0864e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="63ac080c-560a-401c-a3e5-861779daf36d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c5ada6b4-3ee7-4768-9ab5-32a385dd1607")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c53c8865-5bfe-449e-bf97-86d16fc45bb4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="f67256c9-31ae-47de-91e8-e3fad99eadf8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b7f2d301-c5d5-4563-b80b-7296b538ced5")>,
# ...

# %%
Destination=[]
for i in dst:
    Destination.append(i.text)
Destination
# Out:
# ['Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
# ...

# %%
pr=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
pr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="a168004c-c0dd-4e3e-b643-51e6d6e7fd72")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="58a8c024-dbd7-4f5b-bd6f-1804ddf3e84c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="5956e891-128a-4348-9e65-13d937cb519a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="b00403ed-cc31-43f5-b0ca-a535f649353c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="90d34aa2-533e-4ae4-a3d7-e2cffe4678c2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="3ab626b9-39b2-4d59-a124-f1b429f74a27")>,
# ...

# %%
Price=[]
for i in pr:
    Price.append(i.text)
Price
# Out:
# ['1,890',
#  '1,890',
#  '2,194',
#  '2,762',
#  '2,762',
#  '2,773',
#  '2,773',
#  '2,773',
#  '2,773',
#  '2,773',
#  '2,773',
#  '2,773',
#  '2,773',
#  '2,799',
#  '2,799',
#  '2,799',
#  '2,799',
#  '3,318',
#  '3,318',
#  '3,407',
#  '3,407',
#  '3,407',
#  '3,623',
#  '3,644',
#  '3,702',
#  '3,702',
#  '3,702',
#  '3,702',
#  '3,844',
#  '3,844',
#  '4,417',
#  '4,417',
#  '4,417',
#  '4,417',
#  '4,417',
#  '4,417',
#  '4,417',
#  '4,417',
#  '4,417',
#  '4,417',
#  '4,417',
#  '4,417',
#  '4,463',
#  '4,463',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '4,747',
#  '5,062',
#  '5,062',
#  '5,062',
#  '5,220',
#  '5,220',
#  '5,380',
#  '6,085',
#  '6,201',
#  '6,334',
#  '6,334',
#  '6,461',
#  '6,600',
#  '6,600',
#  '7,495',
#  '7,531',
#  '7,574',
#  '7,594',
#  '7,594',
#  '7,594',
#  '7,594',
#  '7,594',
# ...

# %%
df=pd.DataFrame({"Airline":Airline,"Arrival":Arrival,"Departure":Departure,"Duration":Duration,"Source":Source,"Destination":Destination,"Price":Price})
df
# Out:
#        Airline Arrival Departure Duration  Source Destination  Price
# 0    Air India   05:20     07:15   1h 55m  Mumbai     Chennai  1,890
# 1    Air India   09:00     10:55   1h 55m  Mumbai     Chennai  1,890
# 2     SpiceJet   19:55     21:45   1h 50m  Mumbai     Chennai  2,194
# 3     Go First   05:50     07:45   1h 55m  Mumbai     Chennai  2,762
# 4     Go First   18:40     20:40   2h 00m  Mumbai     Chennai  2,762
# ..         ...     ...       ...      ...     ...         ...    ...
# 107    Vistara   07:00     20:15  13h 15m  Mumbai     Chennai  9,127
# 108    Vistara   07:00     20:15  13h 15m  Mumbai     Chennai  9,127
# 109    Vistara   08:45     20:15  11h 30m  Mumbai     Chennai  9,137
# 110    Vistara   10:25     20:15   9h 50m  Mumbai     Chennai  9,452
# 111    Vistara   10:25     22:45  12h 20m  Mumbai     Chennai  9,452
#
# [112 rows x 7 columns]

# %%
#chennai to Delhi

# %%
ar=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
ar
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="e857a16c-bda2-4d0e-84f6-0adc33ed124e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="8412dede-0d9d-4afa-999b-8fcf41158785")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="15d2d1f2-b614-4269-9d4a-1fae93fd762a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="2ae47ada-5303-464d-84d7-bac8b534ad88")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="d80ea2d3-7448-4714-ae78-012357e3c18c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="9bd8d0b3-0c73-4638-9baa-9ac9f53440ab")>,
# ...

# %%
Airline=[]
for i in ar:
    Airline.append(i.text)
Airline
# Out:
# ['Air India',
#  'Air India',
#  'Air India',
#  'SpiceJet',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Air Asia',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Air Asia',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
# ...

# %%
arr=driver.find_elements_by_xpath("//div[@class='i-b pr']")
arr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="4cf2c258-e655-4a72-827a-717b51e72d57")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="ba95c9a1-3db6-4d52-bd17-bc3a7f5da030")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="fc57bd5f-d211-43b2-8af3-a6664259e035")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="da91a2c4-3984-4ba2-942f-2216c17c1a81")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="95dd0275-982b-4e35-b633-52547fc333c5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a33c7626a6ec8d8dbbe11542da9e97f", element="c2a8ffa6-d97a-4dda-a83d-7989c0ae0798")>,
# ...

# %%
Arrival=[]
for i in arr:
    Arrival.append(i.text)
Arrival
# Out:
# ['06:10',
#  '17:00',
#  '09:55',
#  '07:05',
#  '22:05',
#  '17:25',
#  '07:05',
#  '21:05',
#  '18:15',
#  '14:05',
#  '16:20',
#  '19:35',
#  '22:30',
#  '08:30',
#  '08:30',
#  '08:30',
#  '19:40',
#  '17:00',
#  '18:10',
#  '12:00',
#  '18:10',
#  '15:50',
#  '17:00',
#  '17:00',
#  '15:50',
#  '09:55',
#  '15:50',
#  '12:00',
#  '19:10',
#  '19:10',
#  '19:10',
#  '06:25',
#  '22:45',
#  '21:15',
#  '22:45',
#  '14:55',
#  '14:55',
#  '14:55',
#  '06:05',
#  '10:45',
#  '08:35',
#  '13:05',
#  '06:35',
#  '04:45',
#  '12:00',
#  '09:55',
#  '16:35',
#  '11:20',
#  '11:20',
#  '05:00',
#  '13:45',
#  '13:45',
#  '05:00',
#  '13:45',
#  '05:00',
#  '13:45',
#  '21:55',
#  '06:25',
#  '05:00',
#  '11:00',
#  '06:25',
#  '21:55',
#  '06:25',
#  '13:45',
#  '17:00',
#  '15:30',
#  '22:35',
#  '15:50',
#  '23:30',
#  '22:35',
#  '15:50',
#  '14:55',
#  '14:55',
#  '14:55',
#  '06:55',
#  '20:25',
#  '20:25',
#  '20:25',
#  '09:05',
#  '09:05',
#  '06:55',
#  '17:00',
#  '10:55',
# ...

# %%
dept=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Departure=[]
for i in dept:
    Departure.append(i.text.replace("\n"," "))
Departure
# Out:
# ['08:55',
#  '19:50',
#  '13:00',
#  '09:50',
#  '00:50 + 1 day',
#  '20:10',
#  '09:55',
#  '23:55',
#  '21:05',
#  '17:00',
#  '19:15',
#  '22:30',
#  '01:25 + 1 day',
#  '18:30',
#  '08:55 + 1 day',
#  '12:20 + 1 day',
#  '00:50 + 1 day',
#  '22:35',
#  '00:05 + 1 day',
#  '18:25',
#  '00:50 + 1 day',
#  '22:35',
#  '00:05 + 1 day',
#  '00:50 + 1 day',
#  '00:05 + 1 day',
#  '18:25',
#  '00:50 + 1 day',
#  '22:35',
#  '08:55 + 1 day',
#  '12:20 + 1 day',
#  '18:30 + 1 day',
#  '13:50',
#  '07:15 + 1 day',
#  '07:15 + 1 day',
#  '09:25 + 1 day',
#  '20:30',
#  '21:15',
#  '10:15 + 1 day',
#  '08:55',
#  '13:35',
#  '11:30',
#  '00:30 + 1 day',
#  '12:05',
#  '12:05',
#  '20:10',
#  '20:10',
#  '02:10 + 1 day',
#  '18:00',
#  '22:45',
#  '12:25',
#  '21:10',
#  '22:55',
#  '14:20',
#  '23:30',
#  '15:55',
#  '01:10 + 1 day',
#  '09:35 + 1 day',
#  '21:30',
#  '10:15',
#  '22:25',
#  '12:30',
#  '12:30 + 1 day',
#  '22:35',
#  '01:55 + 1 day',
#  '01:00 + 1 day',
#  '01:55 + 1 day',
# ...

# %%
dur=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Duration=[]
for i in dur:
    Duration.append(i.text)
Duration

sr=driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
Source=[]
for i in sr:
    Source.append(i.text)
Source

dst=driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]")
Destination=[]
for i in dst:
    Destination.append(i.text)
Destination

pr=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
Price=[]
for i in pr:
    Price.append(i.text)
Price

df=pd.DataFrame({"Airline":Airline,"Arrival":Arrival,"Departure":Departure,"Duration":Duration,"Source":Source,"Destination":Destination,"Price":Price})
df
# Out:
#        Airline Arrival      Departure Duration   Source Destination   Price
# 0    Air India   06:10          08:55   2h 45m  Chennai   New Delhi   2,271
# 1    Air India   17:00          19:50   2h 50m  Chennai   New Delhi   2,271
# 2    Air India   09:55          13:00   3h 05m  Chennai   New Delhi   2,271
# 3     SpiceJet   07:05          09:50   2h 45m  Chennai   New Delhi   2,730
# 4     SpiceJet   22:05  00:50 + 1 day   2h 45m  Chennai   New Delhi   2,730
# ..         ...     ...            ...      ...      ...         ...     ...
# 137    Vistara   07:00          12:40   5h 40m  Chennai   New Delhi   9,000
# 138    Vistara   20:30  12:40 + 1 day  16h 10m  Chennai   New Delhi   9,000
# 139   Go First   06:30          20:35  14h 05m  Chennai   New Delhi  10,082
# 140  Air India   05:55          17:45  11h 50m  Chennai   New Delhi  12,751
# 141  Air India   05:55          14:35   8h 40m  Chennai   New Delhi  15,691
#
# [142 rows x 7 columns]

# %%
#mum to dehradun

# %%
ar=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
Airline=[]
for i in ar:
    Airline.append(i.text)
Airline

arr=driver.find_elements_by_xpath("//div[@class='i-b pr']")
Arrival=[]
for i in arr:
    Arrival.append(i.text)
Arrival

dept=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Departure=[]
for i in dept:
    Departure.append(i.text.replace("\n"," "))
Departure

durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Duration=[]
for i in durr:
    Duration.append(i.text)
Duration

sr=driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
Source=[]
for i in sr:
    Source.append(i.text)
Source

dest=driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]")
Destination=[]
for i in dest:
    Destination.append(i.text)
Destination

pr=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
Price=[]
for i in pr:
    Price.append(i.text)
Price

df=pd.DataFrame({"Airline":Airline,"Arrival":Arrival,"Departure":Departure,"Duration":Duration,"Source":Source,"Destination":Destination,"Price":Price})
df
# Out:
#       Airline Arrival      Departure Duration  Source Destination   Price
# 0    Go First   10:10          15:05   4h 55m  Mumbai    Dehradun   3,799
# 1    Go First   23:00  12:15 + 1 day  13h 15m  Mumbai    Dehradun   3,799
# 2    Go First   21:15  12:15 + 1 day  15h 00m  Mumbai    Dehradun   3,799
# 3    Go First   08:05          12:15   4h 10m  Mumbai    Dehradun   3,923
# 4    Go First   08:05          15:05   7h 00m  Mumbai    Dehradun   3,923
# ..        ...     ...            ...      ...     ...         ...     ...
# 64  Air India   19:00  13:45 + 1 day  18h 45m  Mumbai    Dehradun   6,794
# 65  Air India   05:00          19:15  14h 15m  Mumbai    Dehradun   7,807
# 66     IndiGo   08:30          19:15  10h 45m  Mumbai    Dehradun   8,826
# 67     IndiGo   02:40          08:20   5h 40m  Mumbai    Dehradun  11,780
# 68     IndiGo   22:20  08:20 + 1 day  10h 00m  Mumbai    Dehradun  11,780
#
# [69 rows x 7 columns]

# %%
ar=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
Airline=[]
for i in ar:
    Airline.append(i.text)
Airline

arr=driver.find_elements_by_xpath("//div[@class='i-b pr']")
Arrival=[]
for i in arr:
    Arrival.append(i.text)
Arrival

dept=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Departure=[]
for i in dept:
    Departure.append(i.text.replace("\n"," "))
Departure

durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Duration=[]
for i in durr:
    Duration.append(i.text)
Duration

sr=driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
Source=[]
for i in sr:
    Source.append(i.text)
Source

dest=driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]")
Destination=[]
for i in dest:
    Destination.append(i.text)
Destination

pr=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
Price=[]
for i in pr:
    Price.append(i.text)
Price

df=pd.DataFrame({"Airline":Airline,"Arrival":Arrival,"Departure":Departure,"Duration":Duration,"Source":Source,"Destination":Destination,"Price":Price})
df
# Out:
#       Airline Arrival      Departure Duration  Source Destination  Price
# 0    Air Asia   22:55  01:00 + 1 day   2h 05m  Mumbai   New Delhi  2,322
# 1    Air Asia   07:20          09:30   2h 10m  Mumbai   New Delhi  2,322
# 2    Go First   23:55  01:55 + 1 day   2h 00m  Mumbai   New Delhi  2,339
# 3    Go First   06:00          08:05   2h 05m  Mumbai   New Delhi  2,339
# 4    Go First   13:50          15:55   2h 05m  Mumbai   New Delhi  2,339
# ..        ...     ...            ...      ...     ...         ...    ...
# 159  Go First   10:50          17:40   6h 50m  Mumbai   New Delhi  6,031
# 160  SpiceJet   18:35          22:10   3h 35m  Mumbai   New Delhi  6,043
# 161  Go First   12:00          19:20   7h 20m  Mumbai   New Delhi  9,092
# 162  Go First   12:00          19:50   7h 50m  Mumbai   New Delhi  9,092
# 163  Go First   12:00          20:50   8h 50m  Mumbai   New Delhi  9,092
#
# [164 rows x 7 columns]

# %%
ar=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
Airline=[]
for i in ar:
    Airline.append(i.text)
Airline

arr=driver.find_elements_by_xpath("//div[@class='i-b pr']")
Arrival=[]
for i in arr:
    Arrival.append(i.text)
Arrival

dept=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
Departure=[]
for i in dept:
    Departure.append(i.text.replace("\n"," "))
Departure

durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
Duration=[]
for i in durr:
    Duration.append(i.text)
Duration

sr=driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
Source=[]
for i in sr:
    Source.append(i.text)
Source

dest=driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]")
Destination=[]
for i in dest:
    Destination.append(i.text)
Destination

pr=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
Price=[]
for i in pr:
    Price.append(i.text)
Price

df=pd.DataFrame({"Airline":Airline,"Arrival":Arrival,"Departure":Departure,"Duration":Duration,"Source":Source,"Destination":Destination,"Price":Price})
df
# Out:
#       Airline Arrival      Departure Duration  Source Destination  Price
# 0   Air India   05:05          06:25   1h 20m  Mumbai         Goa  1,890
# 1   Air India   13:25          14:45   1h 20m  Mumbai         Goa  1,890
# 2   Air India   21:00          22:25   1h 25m  Mumbai         Goa  1,890
# 3    Go First   05:00          06:15   1h 15m  Mumbai         Goa  1,998
# 4    Air Asia   23:35  00:35 + 1 day   1h 00m  Mumbai         Goa  2,000
# ..        ...     ...            ...      ...     ...         ...    ...
# 85    Vistara   07:00  11:40 + 1 day  28h 40m  Mumbai         Goa  8,549
# 86    Vistara   07:00  11:40 + 1 day  28h 40m  Mumbai         Goa  8,549
# 87    Vistara   07:00  13:50 + 1 day  30h 50m  Mumbai         Goa  8,549
# 88    Vistara   07:00  13:50 + 1 day  30h 50m  Mumbai         Goa  8,549
# 89    Vistara   07:00  13:50 + 1 day  30h 50m  Mumbai         Goa  8,549
#
# [90 rows x 7 columns]

# %%
df=[df,df,df,df,df,df,df,df,df,df,df,df]

# %%
results = pd.concat(df)
results
# Out:
#       Airline Arrival      Departure Duration  Source Destination  Price
# 0   Air India   05:05          06:25   1h 20m  Mumbai         Goa  1,890
# 1   Air India   13:25          14:45   1h 20m  Mumbai         Goa  1,890
# 2   Air India   21:00          22:25   1h 25m  Mumbai         Goa  1,890
# 3    Go First   05:00          06:15   1h 15m  Mumbai         Goa  1,998
# 4    Air Asia   23:35  00:35 + 1 day   1h 00m  Mumbai         Goa  2,000
# ..        ...     ...            ...      ...     ...         ...    ...
# 85    Vistara   07:00  11:40 + 1 day  28h 40m  Mumbai         Goa  8,549
# 86    Vistara   07:00  11:40 + 1 day  28h 40m  Mumbai         Goa  8,549
# 87    Vistara   07:00  13:50 + 1 day  30h 50m  Mumbai         Goa  8,549
# 88    Vistara   07:00  13:50 + 1 day  30h 50m  Mumbai         Goa  8,549
# 89    Vistara   07:00  13:50 + 1 day  30h 50m  Mumbai         Goa  8,549
#
# [1080 rows x 7 columns]

# %%
df=results
df
# Out:
#       Airline Arrival      Departure Duration  Source Destination  Price
# 0   Air India   05:05          06:25   1h 20m  Mumbai         Goa  1,890
# 1   Air India   13:25          14:45   1h 20m  Mumbai         Goa  1,890
# 2   Air India   21:00          22:25   1h 25m  Mumbai         Goa  1,890
# 3    Go First   05:00          06:15   1h 15m  Mumbai         Goa  1,998
# 4    Air Asia   23:35  00:35 + 1 day   1h 00m  Mumbai         Goa  2,000
# ..        ...     ...            ...      ...     ...         ...    ...
# 85    Vistara   07:00  11:40 + 1 day  28h 40m  Mumbai         Goa  8,549
# 86    Vistara   07:00  11:40 + 1 day  28h 40m  Mumbai         Goa  8,549
# 87    Vistara   07:00  13:50 + 1 day  30h 50m  Mumbai         Goa  8,549
# 88    Vistara   07:00  13:50 + 1 day  30h 50m  Mumbai         Goa  8,549
# 89    Vistara   07:00  13:50 + 1 day  30h 50m  Mumbai         Goa  8,549
#
# [1080 rows x 7 columns]

# %% [markdown]
# # Data Analysis

# %% [raw]
# 1.Do airfares change frequently?
#   Yes. As we move toward the date of departure, it increases.
# 2.Do they move in small increments or in large jumps?
#   They move in small increments, depending on the class we selected.
# 3. Do they tend to go up or down over time?
#    No.but upwards as we moved towards our date.
# 4.What is the best time to buy so that the consumer can save the most by taking the least risk?
#   Best time would be prior to at least 3-4 month from our date of journey.
# 5.Does price increase as we get near to departure date?
#   Yes.
# 6.Is Indigo cheaper than Jet Airways?
#   Jet Airways is no longer avaliable, but yes when it was available in the past it was cheaper than Indigo
# 7.Are morning flights expensive?
#   No. Rate of flights is direcetly proportional to the frequency of the flights.

# %% [markdown]
# # Data Preprocessing

# %%
df.isnull().sum()
# Out:
# Airline        0
# Arrival        0
# Departure      0
# Duration       0
# Source         0
# Destination    0
# Price          0
# dtype: int64

# %%
# no such null values

# %%
df.dtypes
# Out:
# Airline        object
# Arrival        object
# Departure      object
# Duration       object
# Source         object
# Destination    object
# Price          object
# dtype: object

# %% [markdown]
# # Encoding Dataset

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.columns:
    df[i]=le.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
#     Airline  Arrival  Departure  Duration  Source  Destination  Price
# 0         1        3          5        33       0            0      0
# 1         1       26         14        33       0            0      0
# 2         1       50         29        34       0            0      0
# 3         2        2          4        32       0            0      1
# 4         0       58          0        30       0            0      2
# ..      ...      ...        ...       ...     ...          ...    ...
# 85        5        9          6        45       0            0     27
# 86        5        9          6        45       0            0     27
# 87        5        9         13        47       0            0     27
# ...

# %%
df.dtypes
# Out:
# Airline        int64
# Arrival        int64
# Departure      int64
# Duration       int64
# Source         int64
# Destination    int64
# Price          int64
# dtype: object

# %% [markdown]
# # Visualization of DataSet

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='Airline',data=df)
print(df['Airline'].value_counts())
# Out:
# 5    468
# 2    204
# 1    204
# 0     96
# 3     60
# 4     48
# Name: Airline, dtype: int64

# %%
sns.histplot(x='Arrival',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='Arrival', ylabel='Count'>

# %%
sns.histplot(x='Departure',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='Departure', ylabel='Count'>

# %%
sns.histplot(x='Duration',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Count'>

# %%
sns.countplot(x='Source',data=df)
print(df['Source'].value_counts())
# Out:
# 0    1080
# Name: Source, dtype: int64

# %%
sns.countplot(x='Destination',data=df)
print(df['Destination'].value_counts())
# Out:
# 0    1080
# Name: Destination, dtype: int64

# %%
sns.histplot(x='Price',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %% [markdown]
# # Describing Datasets

# %%
df.describe()
# Out:
#            Airline      Arrival    Departure     Duration  Source  \
# count  1080.000000  1080.000000  1080.000000  1080.000000  1080.0
# mean      3.077778    28.911111    13.355556    31.422222     0.0
# std       1.876015    17.869869     9.277089    15.724914     0.0
# min       0.000000     0.000000     0.000000     0.000000     0.0
# 25%       1.000000    11.000000     6.000000    19.000000     0.0
# 50%       3.000000    30.000000    13.000000    34.000000     0.0
# 75%       5.000000    45.000000    19.000000    45.000000     0.0
# max       5.000000    59.000000    33.000000    59.000000     0.0
#
#        Destination        Price
# count       1080.0  1080.000000
# mean           0.0    15.444444
# std            0.0     7.735351
# min            0.0     0.000000
# 25%            0.0     9.000000
# 50%            0.0    18.000000
# 75%            0.0    21.000000
# max            0.0    27.000000

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidth=0.2,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#               Airline   Arrival  Departure  Duration  Source  Destination  \
# Airline      1.000000  0.015135  -0.236109  0.122917     NaN          NaN
# Arrival      0.015135  1.000000   0.093842 -0.285696     NaN          NaN
# Departure   -0.236109  0.093842   1.000000 -0.184377     NaN          NaN
# Duration     0.122917 -0.285696  -0.184377  1.000000     NaN          NaN
# Source            NaN       NaN        NaN       NaN     NaN          NaN
# Destination       NaN       NaN        NaN       NaN     NaN          NaN
# Price        0.537146 -0.040264  -0.308129  0.189180     NaN          NaN
#
#                 Price
# Airline      0.537146
# Arrival     -0.040264
# Departure   -0.308129
# Duration     0.189180
# Source            NaN
# Destination       NaN
# Price        1.000000

# %%
df=df.drop('Source',axis=1)

# %%
df.drop('Destination',axis=1)

# %%
df
# Out:
#     Airline  Arrival  Departure  Duration  Price
# 0         1        3          5        33      0
# 1         1       26         14        33      0
# 2         1       50         29        34      0
# 3         2        2          4        32      1
# 4         0       58          0        30      2
# ..      ...      ...        ...       ...    ...
# 85        5        9          6        45     27
# 86        5        9          6        45     27
# 87        5        9         13        47     27
# 88        5        9         13        47     27
# 89        5        9         13        47     27
#
# [1080 rows x 5 columns]

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.2,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers Checking

# %%
df.skew()
# Out:
# Airline     -0.214119
# Arrival      0.011034
# Departure    0.582334
# Duration    -0.298154
# Price       -0.338740
# dtype: float64

# %% [markdown]
# There are no outliers present,data is clean. Now we can head towards Model building.

# %% [markdown]
# # Model Building

# %% [markdown]
# Separation of x and y into feature and label

# %%
x=df.drop('Price',axis=1)
y=df['Price']

# %%
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[-1.10233147, -1.62845828, -0.85217162,  0.10788493],
#        [-1.10233147, -0.0327754 ,  0.23634206,  0.10788493],
#        [-1.10233147,  1.11620033,  1.4801751 ,  0.17102953],
#        ...,
#        [ 1.01488027, -1.10033816,  0.13523371,  0.98775716],
#        [ 1.01488027, -1.10033816,  0.13523371,  0.98775716],
#        [ 1.01488027, -1.10033816,  0.13523371,  0.98775716]])

# %% [markdown]
# Scaling Dataset

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-1.10233147, -1.62845828, -0.85217162,  0.10788493],
#        [-1.10233147, -0.0327754 ,  0.23634206,  0.10788493],
#        [-1.10233147,  1.11620033,  1.4801751 ,  0.17102953],
#        ...,
#        [ 1.01488027, -1.10033816,  0.13523371,  0.98775716],
#        [ 1.01488027, -1.10033816,  0.13523371,  0.98775716],
#        [ 1.01488027, -1.10033816,  0.13523371,  0.98775716]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
from sklearn.svm import SVR
svr=SVR(kernel='rbf')
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'At random state {i}, the training accuracy is :-{r2_score(y_train,pred_train)}')
    print(f'At random state {i}, the testing accuracy is :-{r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At random state 0, the training accuracy is :-0.34690783442189
# At random state 0, the testing accuracy is :-0.2494225973650107
#
#
# At random state 1, the training accuracy is :-0.3214772758884874
# At random state 1, the testing accuracy is :-0.3519394058605795
#
#
# At random state 2, the training accuracy is :-0.33266577607158776
# At random state 2, the testing accuracy is :-0.3042082625133833
#
#
# At random state 3, the training accuracy is :-0.3203083656892477
# At random state 3, the testing accuracy is :-0.35551958530925754
#
#
# At random state 4, the training accuracy is :-0.3186453498113315
# At random state 4, the testing accuracy is :-0.35746246287714933
#
#
# At random state 5, the training accuracy is :-0.330371164080578
# At random state 5, the testing accuracy is :-0.31660270383440514
#
#
# At random state 6, the training accuracy is :-0.3307922148804012
# At random state 6, the testing accuracy is :-0.31490276375407755
#
#
# ...

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    dtr.fit(x_train,y_train)
    pred_train=dtr.predict(x_train)
    pred_test=dtr.predict(x_test)
    print(f'At random state {i}, the training accuracy is :-{r2_score(y_train,pred_train)}')
    print(f'At random state {i}, the testing accuracy is :-{r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At random state 0, the training accuracy is :-1.0
# At random state 0, the testing accuracy is :-1.0
#
#
# At random state 1, the training accuracy is :-1.0
# At random state 1, the testing accuracy is :-1.0
#
#
# At random state 2, the training accuracy is :-1.0
# At random state 2, the testing accuracy is :-1.0
#
#
# At random state 3, the training accuracy is :-1.0
# At random state 3, the testing accuracy is :-1.0
#
#
# At random state 4, the training accuracy is :-1.0
# At random state 4, the testing accuracy is :-1.0
#
#
# At random state 5, the training accuracy is :-1.0
# At random state 5, the testing accuracy is :-1.0
#
#
# At random state 6, the training accuracy is :-1.0
# At random state 6, the testing accuracy is :-1.0
#
#
# At random state 7, the training accuracy is :-1.0
# At random state 7, the testing accuracy is :-1.0
#
#
# At random state 8, the training accuracy is :-1.0
# At random state 8, the testing accuracy is :-1.0
#
#
# ...

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.747943758210746

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    svr.fit(x_train,y_train)
    pred_train=svr.predict(x_train)
    pred_test=svr.predict(x_test)
    print(f'At random state {i}, the training accuracy is :-{r2_score(y_train,pred_train)}')
    print(f'At random state {i}, the testing accuracy is :-{r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At random state 0, the training accuracy is :-0.7812222403534601
# At random state 0, the testing accuracy is :-0.706829936767267
#
#
# At random state 1, the training accuracy is :-0.7512583801302655
# At random state 1, the testing accuracy is :-0.8051216726288508
#
#
# At random state 2, the training accuracy is :-0.7632656836582663
# At random state 2, the testing accuracy is :-0.7679565569055046
#
#
# At random state 3, the training accuracy is :-0.7583596764943056
# At random state 3, the testing accuracy is :-0.7897069472665268
#
#
# At random state 4, the training accuracy is :-0.7684966434998207
# At random state 4, the testing accuracy is :-0.7509367681798205
#
#
# At random state 5, the training accuracy is :-0.7649346951084612
# At random state 5, the testing accuracy is :-0.742183352199191
#
#
# At random state 6, the training accuracy is :-0.7759661959890676
# At random state 6, the testing accuracy is :-0.7049920937077878
#
#
# ...

# %% [markdown]
# In Linear regression model, Training accuracy is lesser than testing, SO there is a problem of underfitting.
# In support vector regressor model, same problem has occured.
# Decision tree regressor gave the best result. No need to overcome problem of underfitting and overfitting.

# %% [markdown]
# Selecting Decision tree regressor model.

# %% [markdown]
# # Cross validation of the model

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range (2,10):
    cv_score=cross_val_score(dtr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f' At cross fold{j} the cv score is {cv_mean} and the accuracy score for training is {Train_accuracy} and the accuracy score testing is {Test_accuracy}' )
    print('\n')
# Out:
#  At cross fold2 the cv score is 1.0 and the accuracy score for training is 0.7732795288401143 and the accuracy score testing is 0.747943758210746
#
#
#  At cross fold3 the cv score is 1.0 and the accuracy score for training is 0.7732795288401143 and the accuracy score testing is 0.747943758210746
#
#
#  At cross fold4 the cv score is 1.0 and the accuracy score for training is 0.7732795288401143 and the accuracy score testing is 0.747943758210746
#
#
#  At cross fold5 the cv score is 1.0 and the accuracy score for training is 0.7732795288401143 and the accuracy score testing is 0.747943758210746
#
#
#  At cross fold6 the cv score is 1.0 and the accuracy score for training is 0.7732795288401143 and the accuracy score testing is 0.747943758210746
#
#
#  At cross fold7 the cv score is 1.0 and the accuracy score for training is 0.7732795288401143 and the accuracy score testing is 0.747943758210746
#
#
# ...

# %%
plt.figure(figsize=(22,7))
plt.scatter(x=y_test,y=pred_test,color='red')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Wins',fontsize=14)
plt.ylabel('Predicted Wins',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()
